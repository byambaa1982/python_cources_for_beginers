# %% [markdown]
# <a href="https://colab.research.google.com/github/byambaa1982/python_cources_for_beginers/blob/main/Mini%20Project%201/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # Back End
# - Python : pandas
# - SQL
#
# ## Front End
# - HTML
# - CSV

# %%
 df = pd.read_csv('mongol.csv')
 df
# Out:
#               tweet_id                                               text  \
# 0  1751610805676585123  @Uyanga_ts “Энэ дэлхийн ядарсан зүдэрсэн бүхни...
# 1  1751584394492710942  @amarbayarm Нямбаатар дарга явдаг юм. байсан б...
# 2  1751583655498252472  Нямбаатар автобусаан харамлаад байхаар нь ийм ...
# 3  1751546553301680317  Ард түмэний сэтгэл хөдлөл , уур хилэн намдсан ...
# 4  1751534346031259769  Явган хүн хальтирч үхчих гээд аргаа барахдаа и...
# 5  1751509137878650882  Автобус бус Мөсөн тээвэр хөгжүүлж буй Х.Нямбаа...
# 6  1751490869692428698  @ShinegerelR Дээр нь Нямбаатар  нэмээд Нийслэл...
# 7  1751487870806941882  @Uyanga_ts @khasherden10698 Нямбаатар чинь ард...
# 8  1751448327441576041  @Naidalaa Хотын төвд утаа баагиулсан зүтгүүрий...
# 9  1751446993942274254  Сумъяабазарыг сайн ажиллаж байсан мэт санагдта...
#
#                                          media_url                created_at  \
# ...

# %%
df.head()
# Out:
#               tweet_id                                               text  \
# 0  1751610805676585123  @Uyanga_ts “Энэ дэлхийн ядарсан зүдэрсэн бүхни...
# 1  1751584394492710942  @amarbayarm Нямбаатар дарга явдаг юм. байсан б...
# 2  1751583655498252472  Нямбаатар автобусаан харамлаад байхаар нь ийм ...
# 3  1751546553301680317  Ард түмэний сэтгэл хөдлөл , уур хилэн намдсан ...
# 4  1751534346031259769  Явган хүн хальтирч үхчих гээд аргаа барахдаа и...
#
#                                          media_url                created_at  \
# 0                                              NaN  2024-01-28T14:18:54.000Z
# 1                                              NaN  2024-01-28T12:33:57.000Z
# 2                                              NaN  2024-01-28T12:31:00.000Z
# 3  https://pbs.twimg.com/media/GE6-TYJagAA0eYg.jpg  2024-01-28T10:03:35.000Z
# 4                                              NaN  2024-01-28T09:15:04.000Z
#
#              author_id  username
# ...

# %%
df.tail()
# Out:
#               tweet_id                                               text  \
# 5  1751509137878650882  Автобус бус Мөсөн тээвэр хөгжүүлж буй Х.Нямбаа...
# 6  1751490869692428698  @ShinegerelR Дээр нь Нямбаатар  нэмээд Нийслэл...
# 7  1751487870806941882  @Uyanga_ts @khasherden10698 Нямбаатар чинь ард...
# 8  1751448327441576041  @Naidalaa Хотын төвд утаа баагиулсан зүтгүүрий...
# 9  1751446993942274254  Сумъяабазарыг сайн ажиллаж байсан мэт санагдта...
#
#                                          media_url                created_at  \
# 5                                              NaN  2024-01-28T07:34:54.000Z
# 6                                              NaN  2024-01-28T06:22:19.000Z
# 7                                              NaN  2024-01-28T06:10:24.000Z
# 8                                              NaN  2024-01-28T03:33:16.000Z
# 9  https://pbs.twimg.com/media/GE5jv8haAAADlXH.jpg  2024-01-28T03:27:58.000Z
#
#              author_id  username
# ...
