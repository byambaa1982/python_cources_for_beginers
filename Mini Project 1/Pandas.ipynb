# %% [markdown]
# <a href="https://colab.research.google.com/github/byambaa1982/python_cources_for_beginers/blob/class_zero_urangoo/Mini%20Project%201/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Back End
# - Python : pandas
# - SQL
#
# ## Front End
# - HTML
# - CSV

# %%
import pandas as pd

# Create a DataFrame with 10 rows
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Ella', 'Frank', 'Grace', 'Hannah', 'Ian', 'Jack'],
    'Favorite Animal': ['Panda', 'Elephant', 'Giraffe', 'Panda', 'Koala', 'Lion', 'Dolphin', 'Panda', 'Tiger', 'Penguin'],
    'Age': [10, 12, 11, 10, 9, 13, 11, 10, 12, 9],
    'Score': [85, 92, 88, 76, 95, 89, 91, 87, 84, 90],
    'Favorite Color': ['Red', 'Blue', 'Green', 'Yellow', 'Purple', 'Orange', 'Pink', 'Teal', 'Brown', 'Black']
}

df = pd.DataFrame(data)

df
# Out:
#       Name Favorite Animal  Age  Score Favorite Color
# 0    Alice           Panda   10     85            Red
# 1      Bob        Elephant   12     92           Blue
# 2  Charlie         Giraffe   11     88          Green
# 3    David           Panda   10     76         Yellow
# 4     Ella           Koala    9     95         Purple
# 5    Frank            Lion   13     89         Orange
# 6    Grace         Dolphin   11     91           Pink
# 7   Hannah           Panda   10     87           Teal
# 8      Ian           Tiger   12     84          Brown
# 9     Jack         Penguin    9     90          Black

# %%
df[df['Age']==10]
# Out:
#      Name Favorite Animal  Age  Score Favorite Color
# 0   Alice           Panda   10     85            Red
# 3   David           Panda   10     76         Yellow
# 7  Hannah           Panda   10     87           Teal

# %%
df[(df['Age']>=10) & (df['Age']<=11)]
# Out:
#       Name Favorite Animal  Age  Score Favorite Color
# 0    Alice           Panda   10     85            Red
# 2  Charlie         Giraffe   11     88          Green
# 3    David           Panda   10     76         Yellow
# 6    Grace         Dolphin   11     91           Pink
# 7   Hannah           Panda   10     87           Teal

# %%
df[df['Score']==85]
# Out:
#     Name Favorite Animal  Age  Score Favorite Color
# 0  Alice           Panda   10     85            Red

# %%
df[df['Favorite Animal']=='Panda']
# Out:
#      Name Favorite Animal  Age  Score Favorite Color
# 0   Alice           Panda   10     85            Red
# 3   David           Panda   10     76         Yellow
# 7  Hannah           Panda   10     87           Teal

# %%
name_age_score = df [['Name', 'Age', 'Score']]

# %%
name_age_score
# Out:
#       Name  Age  Score
# 0    Alice   10     85
# 1      Bob   12     92
# 2  Charlie   11     88
# 3    David   10     76
# 4     Ella    9     95
# 5    Frank   13     89
# 6    Grace   11     91
# 7   Hannah   10     87
# 8      Ian   12     84
# 9     Jack    9     90

# %%
average_score = df['Score'].mean()
print(f"The average score is {average_score}")
# Out:
# The average score is 87.7

# %%
max_score = df['Score'].max()
print(f"The max score is {max_score}")
# Out:
# The max score is 95

# %%
minimum_score = df['Score'].min()
print(f"The minimum score is {minimum_score}")
# Out:
# The minimum score is 76

# %%
def find_minimum(col):
  minimum_score = df[col].min()
  print(f"The mimimum {col} is {mimimum_score}")

# %%
Create a DataFrame with the following data:
Name	Age	Favorite Subject	Grade
Emma	10	Math	85
Oliver	12	Science	90
Ava	11	History	88
Lucas	10	English	92
Mia	12	Art	95
Print the entire DataFrame to see all the data.

Print only the "Name" and "Favorite Subject" columns.

Calculate and print the average grade of all the students.

Create a new DataFrame that only includes students with a grade higher than 90.

Sort the original DataFrame by the "Age" column in ascending order and print the sorted DataFrame.

Bonus Challenge (Optional)

Find the student with the highest grade and print their name and grade.

# %%
import pandas as pd

# Data
data = {
    'Name': ['emma', 'oliver', 'ava', 'lucas', 'mia'],
    'Favorite subject': ['math', 'science', 'history', 'english', 'art'],
    'Age': [10, 12, 11, 10, 12],
    'grade': [85, 90, 88, 92, 95,]
}

df = pd.DataFrame(data)

df
# Out:
#      Name Favorite subject  Age  grade
# 0    emma             math   10     85
# 1  oliver          science   12     90
# 2     ava          history   11     88
# 3   lucas          english   10     92
# 4     mia              art   12     95

# %%
name_age_score = df [['Name', 'Favorite Subject']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-c536c4582f57> in <cell line: 1>()
# ----> 1 name_age_score = df [['Name', 'Favorite Subject']]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3897             if is_iterator(key):
#    3898                 key = list(key)
# -> 3899             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3900
#    3901         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6113             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6114
# -> 6115         self._raise_if_missing(keyarr, indexer, axis_name)
#    6116
#    6117         keyarr = self.take(indexer)
#
# ...

# %%
average_grade = df['grade'].mean()
print(f"The average grade is {average_grade}")
# Out:
# The average grade is 90.0

# %%
df[df['grade']==90]
# Out:
#      Name Favorite subject  Age  grade
# 1  oliver          science   12     90

# %%
sorted_df = df.sort_values(by='Age', ascending=True)

# %%
print(sorted_df)
# Out:
#      Name Favorite subject  Age  grade
# 0    emma             math   10     85
# 3   lucas          english   10     92
# 2     ava          history   11     88
# 1  oliver          science   12     90
# 4     mia              art   12     95
