# %% [markdown]
# <a href="https://colab.research.google.com/github/byambaa1982/python_cources_for_beginers/blob/class_zero_burentugs/Mini%20Project%201/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Back End
# - Python : pandas
# - SQL
#
# ## Front End
# - HTML
# - CSV

# %%
import pandas as pd

# Create a DataFrame with 10 rows
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Ella', 'Frank', 'Grace', 'Hannah', 'Ian', 'Jack'],
    'Favorite Animal': ['Panda', 'Elephant', 'Giraffe', 'Panda', 'Koala', 'Lion', 'Dolphin', 'Panda', 'Tiger', 'Penguin'],
    'Age': [10, 12, 11, 10, 9, 13, 11, 10, 12, 9],
    'Score': [85, 92, 88, 76, 95, 89, 91, 87, 84, 90],
    'Favorite Color': ['Red', 'Blue', 'Green', 'Yellow', 'Purple', 'Orange', 'Pink', 'Teal', 'Brown', 'Black']
}

df = pd.DataFrame(data)

df
# Out:
#       Name Favorite Animal  Age  Score Favorite Color
# 0    Alice           Panda   10     85            Red
# 1      Bob        Elephant   12     92           Blue
# 2  Charlie         Giraffe   11     88          Green
# 3    David           Panda   10     76         Yellow
# 4     Ella           Koala    9     95         Purple
# 5    Frank            Lion   13     89         Orange
# 6    Grace         Dolphin   11     91           Pink
# 7   Hannah           Panda   10     87           Teal
# 8      Ian           Tiger   12     84          Brown
# 9     Jack         Penguin    9     90          Black

# %%
df[df['Age']==10]
# Out:
#      Name Favorite Animal  Age  Score Favorite Color
# 0   Alice           Panda   10     85            Red
# 3   David           Panda   10     76         Yellow
# 7  Hannah           Panda   10     87           Teal

# %%
df[(df['Age']>=10) & (df['Age']<=12)]
# Out:
#       Name Favorite Animal  Age  Score Favorite Color
# 0    Alice           Panda   10     85            Red
# 1      Bob        Elephant   12     92           Blue
# 2  Charlie         Giraffe   11     88          Green
# 3    David           Panda   10     76         Yellow
# 6    Grace         Dolphin   11     91           Pink
# 7   Hannah           Panda   10     87           Teal
# 8      Ian           Tiger   12     84          Brown

# %%
df[df['Score']==85]
# Out:
#     Name Favorite Animal  Age  Score Favorite Color
# 0  Alice           Panda   10     85            Red

# %%
df[df['Favorite Animal']=='Lion']
# Out:
#     Name Favorite Animal  Age  Score Favorite Color
# 5  Frank            Lion   13     89         Orange

# %%
df[["Name", "Age", "Score"]]
# Out:
#       Name  Age  Score
# 0    Alice   10     85
# 1      Bob   12     92
# 2  Charlie   11     88
# 3    David   10     76
# 4     Ella    9     95
# 5    Frank   13     89
# 6    Grace   11     91
# 7   Hannah   10     87
# 8      Ian   12     84
# 9     Jack    9     90

# %%
name_age_score = df[["Name", "Age", "Score"]]

# %%
name_age_score
# Out:
#       Name  Age  Score
# 0    Alice   10     85
# 1      Bob   12     92
# 2  Charlie   11     88
# 3    David   10     76
# 4     Ella    9     95
# 5    Frank   13     89
# 6    Grace   11     91
# 7   Hannah   10     87
# 8      Ian   12     84
# 9     Jack    9     90

# %%
df[["Name", "Age", "Score", "Favorite Color"]]
# Out:
#       Name  Age  Score Favorite Color
# 0    Alice   10     85            Red
# 1      Bob   12     92           Blue
# 2  Charlie   11     88          Green
# 3    David   10     76         Yellow
# 4     Ella    9     95         Purple
# 5    Frank   13     89         Orange
# 6    Grace   11     91           Pink
# 7   Hannah   10     87           Teal
# 8      Ian   12     84          Brown
# 9     Jack    9     90          Black

# %%
name_age_score_favoritecolor = df[["Name", "Age", "Score", "Favorite Color"]]

# %%
name_age_score_favoritecolor
# Out:
#       Name  Age  Score Favorite Color
# 0    Alice   10     85            Red
# 1      Bob   12     92           Blue
# 2  Charlie   11     88          Green
# 3    David   10     76         Yellow
# 4     Ella    9     95         Purple
# 5    Frank   13     89         Orange
# 6    Grace   11     91           Pink
# 7   Hannah   10     87           Teal
# 8      Ian   12     84          Brown
# 9     Jack    9     90          Black

# %%
name_age_score = df [["Name", "Age", "Score"]]

# %%
name_age_score
# Out:
#       Name  Age  Score
# 0    Alice   10     85
# 1      Bob   12     92
# 2  Charlie   11     88
# 3    David   10     76
# 4     Ella    9     95
# 5    Frank   13     89
# 6    Grace   11     91
# 7   Hannah   10     87
# 8      Ian   12     84
# 9     Jack    9     90

# %%
average_score = df['Score'].mean()
print(f"The average score is {average_score}")
# Out:
# The average score is 87.7

# %%
max_score = df['Score'].max()
print(f"The max score is {max_score}")
# Out:
# The max score is 95

# %%
minimum_score = df['Score'].min()
print(f"The minimum score is {minimum_score}")
# Out:
# The minimum score is 76

# %%
df_sorted = df.sort_values(by= "Score")
df_sorted
# Out:
#       Name Favorite Animal  Age  Score Favorite Color
# 3    David           Panda   10     76         Yellow
# 8      Ian           Tiger   12     84          Brown
# 0    Alice           Panda   10     85            Red
# 7   Hannah           Panda   10     87           Teal
# 2  Charlie         Giraffe   11     88          Green
# 5    Frank            Lion   13     89         Orange
# 9     Jack         Penguin    9     90          Black
# 6    Grace         Dolphin   11     91           Pink
# 1      Bob        Elephant   12     92           Blue
# 4     Ella           Koala    9     95         Purple

# %%
def find_average(col):
  average_score = df[col].mean()
  print(f"The average {col} is {average_score}")

# %%
find_average('Age')
find_average('Score')
# Out:
# The average Age is 10.7
# The average Score is 87.7

# %%
def find_maximum(col):
  maximum_score = df[col].max()
  print(f"The maximum {col} is {maximum_score}")

# %%
find_maximum('Age')
find_maximum('Score')
# Out:
# The maximum Age is 13
# The maximum Score is 95
