# %% [markdown]
# <a href="https://colab.research.google.com/github/byambaa1982/python_cources_for_beginers/blob/main/Mini%20Project%201/Pandas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Handling Missing Data

# %%
import pandas as pd

# %%
data = {
    'Name': ['Emma', 'Oliver', 'Ava', 'Lucas', 'Mia'],
    'Age': [10, 12, None, 10, 12],
    'Grade': [85, None, 88, 92, 95]
}
df = pd.DataFrame(data)
df
# Out:
#      Name   Age  Grade
# 0    Emma  10.0   85.0
# 1  Oliver  12.0    NaN
# 2     Ava   NaN   88.0
# 3   Lucas  10.0   92.0
# 4     Mia  12.0   95.0

# %%
df_clean = df.fillna(5)
df_clean
# Out:
#      Name   Age  Grade
# 0    Emma  10.0   85.0
# 1  Oliver  12.0    5.0
# 2     Ava   5.0   88.0
# 3   Lucas  10.0   92.0
# 4     Mia  12.0   95.0
