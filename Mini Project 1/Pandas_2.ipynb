# %% [markdown]
# <a href="https://colab.research.google.com/github/byambaa1982/python_cources_for_beginers/blob/class_zero_enko/Mini%20Project%201/Pandas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Handling Missing Data

# %%
import pandas as pd

# %%
data = {
    'Name': ['Emma', 'Oliver', 'Ava', 'Lucas', 'Mia'],
    'id': [10, 12, None, 10, 12],
    'Grade': [85, None, 88, 92, 95]
}
df = pd.DataFrame(data)
df
# Out:
#      Name    id  Grade
# 0    Emma  10.0   85.0
# 1  Oliver  12.0    NaN
# 2     Ava   NaN   88.0
# 3   Lucas  10.0   92.0
# 4     Mia  12.0   95.0

# %%
df_clean = df.fillna(5)
df_clean
# Out:
#      Name    id  Grade
# 0    Emma  10.0   85.0
# 1  Oliver  12.0    5.0
# 2     Ava   5.0   88.0
# 3   Lucas  10.0   92.0
# 4     Mia  12.0   95.0

# %%
df_clean = df.fillna(3)
df_clean
# Out:
#      Name    id  Grade
# 0    Emma  10.0   85.0
# 1  Oliver  12.0    3.0
# 2     Ava   3.0   88.0
# 3   Lucas  10.0   92.0
# 4     Mia  12.0   95.0

# %%
grouped_df = df.groupby('Age').mean(numeric_only = True)
grouped_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-a43ffc109192> in <cell line: 1>()
# ----> 1 grouped_df = df.groupby('Age').mean(numeric_only = True)
#       2 grouped_df
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8867             raise TypeError("You have to supply one of 'by' and 'level'")
#    8868
# -> 8869         return DataFrameGroupBy(
#    8870             obj=self,
#    8871             keys=by,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1276
#    1277         if grouper is None:
# -> 1278             grouper, exclusions, obj = get_grouper(
#    1279                 obj,
# ...

# %%
data1 = {
    'Name': ['Emma', 'Oliver', 'Ava'],
    'Grade': [45, 90, 88],
    'id': [1,2,3]
}

data2 = {
    'Name': ['Emma', 'Oliver', 'Lucas'],
    'Age': [10, 12, 10],
    'id': [1, 2,4]
}

# %%
df1 = pd.DataFrame(data1)
df1
# Out:
#      Name  Grade  id
# 0    Emma     45   1
# 1  Oliver     90   2
# 2     Ava     88   3

# %%
df2 = pd.DataFrame(data2)
df2
# Out:
#      Name  Age  id
# 0    Emma   10   1
# 1  Oliver   12   2
# 2   Lucas   10   4

# %%
outer_merged_df = pd.merge(df1, df2, on = 'Name', how = 'outer')
outer_merged_df
# Out:
#      Name  Grade  id_x   Age  id_y
# 0    Emma   45.0   1.0  10.0   1.0
# 1  Oliver   90.0   2.0  12.0   2.0
# 2     Ava   88.0   3.0   NaN   NaN
# 3   Lucas    NaN   NaN  10.0   4.0

# %%
left_df = pd.merge(df1, df2, on = 'Name', how = 'left')
left_df
# Out:
#      Name  Grade  id_x   Age  id_y
# 0    Emma     45     1  10.0   1.0
# 1  Oliver     90     2  12.0   2.0
# 2     Ava     88     3   NaN   NaN

# %%
right_df = pd.merge(df1, df2, on = 'Name', how = 'right')
right_df
# Out:
#      Name  Grade  id_x  Age  id_y
# 0    Emma   45.0   1.0   10     1
# 1  Oliver   90.0   2.0   12     2
# 2   Lucas    NaN   NaN   10     4

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
df1.plot(kind='bar', x='Name', y='Grade')
# Out:
# <Axes: xlabel='Name'>

# %%
df.plot(kind='bar', x='Name', y= 'Age')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-f0c54384cef1> in <cell line: 1>()
# ----> 1 df.plot(kind='bar', x='Name', y= 'Age')
#
# ...

# %%
# Bar chart of Grades
plt.figure(figsize=(8, 5))
df['Grade'].plot(kind='bar', color='orange')
plt.title('Grades of Students')
plt.xlabel('Student Index')
plt.ylabel('Grade')
plt.xticks(ticks=range(len(df['Name'])), labels=df['Name'])
plt.show()

# %% [markdown]
# #Homework

# %%
data1 = {
    'Name': ['Emma', 'Oliver', 'Ava', 'Ricardo', 'Lex', 'Mike', 'Michael', 'Tim', 'Annie',],
    'Math_Grade': [45, 90, 88, 70, 95, 90, 70, 50, 55],
    'id': [1,2,3,4,5,6,7,8,9]
}

data2 = {
    'Name': ['Emma', 'Oliver', 'Ava', 'Ricardo', 'Lex', 'Mike', 'Michael', 'Tim', 'Bill',],
    'Science_Grade': [90, 80, 75, 60, 65, 85, 70, 50, 55],
    'id': [1,2,3,4,5,6,7,8,10]
}

# %%
df1 = pd.DataFrame(data1)
df1
# Out:
#       Name  Math_Grade  id
# 0     Emma          45   1
# 1   Oliver          90   2
# 2      Ava          88   3
# 3  Ricardo          70   4
# 4      Lex          95   5
# 5     Mike          90   6
# 6  Michael          70   7
# 7      Tim          50   8
# 8    Annie          55   9

# %%
df2 = pd.DataFrame(data2)
df2
# Out:
#       Name  Science_Grade  id
# 0     Emma             90   1
# 1   Oliver             80   2
# 2      Ava             75   3
# 3  Ricardo             60   4
# 4      Lex             65   5
# 5     Mike             85   6
# 6  Michael             70   7
# 7      Tim             50   8
# 8     Bill             55  10

# %%
outer_merged_df = pd.merge(df1, df2, on = 'Name', how = 'outer')
outer_merged_df
# Out:
#       Name  Math_Grade  id_x  Science_Grade  id_y
# 0     Emma        45.0   1.0           90.0   1.0
# 1   Oliver        90.0   2.0           80.0   2.0
# 2      Ava        88.0   3.0           75.0   3.0
# 3  Ricardo        70.0   4.0           60.0   4.0
# 4      Lex        95.0   5.0           65.0   5.0
# 5     Mike        90.0   6.0           85.0   6.0
# 6  Michael        70.0   7.0           70.0   7.0
# 7      Tim        50.0   8.0           50.0   8.0
# 8    Annie        55.0   9.0            NaN   NaN
# 9     Bill         NaN   NaN           55.0  10.0

# %%
def find_average(df,col):
  average_grade = df[col].mean()
  print(f"The average {col} is {average_grade}")

# %%
find_average(df1,'Math_Grade')
# Out:
# The average Math_Grade is 72.55555555555556

# %%
find_average(df2,'Science_Grade')
# Out:
# The average Science_Grade is 70.0

# %%
outer_merged_df = pd.merge(df1, df2, on = 'Name', how = 'outer')
outer_merged_df

# %%
df1[(df1['Math_Grade']>=90) & (df1['Math_Grade']<=100)]
# Out:
#      Name  Math_Grade  id
# 1  Oliver          90   2
# 4     Lex          95   5
# 5    Mike          90   6

# %%
df2[(df2['Science_Grade']>=90) & (df2['Science_Grade']<=100)]
# Out:
#    Name  Science_Grade  id
# 0  Emma             90   1

# %%
df1_sorted = df.sort_values(by= "Grade")
df1_sorted
# Out:
#      Name    id  Grade
# 0    Emma  10.0   85.0
# 2     Ava   NaN   88.0
# 3   Lucas  10.0   92.0
# 4     Mia  12.0   95.0
# 1  Oliver  12.0    NaN
