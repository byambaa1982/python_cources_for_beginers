# %% [markdown]
# <a href="https://colab.research.google.com/github/byambaa1982/python_cources_for_beginers/blob/byamba_project1_step1/Mini%20Project%201/Step_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = '''
Maria is a student at a university. She likes to write poetry in her free time. Her latest poem is called "The Sunflower". 
She is planning to submit it to a poetry contest, and she needs to send it to the organizers via email. 
Can you help her make some changes to the poem using string methods?

Here is her contact information:
Email: maria.poet@gmail.com
Phone number: 555-1234
'''

# %% [markdown]
# ### Tasks:
#
# 1. Change all the letters in the poem to lowercase.
# 2. Replace the word "sunflower" with the word "rose".
# 3. Remove all the spaces from the poem.
# 4. Count how many times the word "love" appears in the poem.
# 5. Create a new string that includes Maria's contact information in this format:
# "Maria can be reached at maria.poet@gmail.com or 555-1234."
# 6. Create a new string that includes the first four letters of each word in the poem, capitalized. For example, "The Sunflower" would become "TSun".

# %%
make_lower = text.lower()

# %%
make_lower
# Out:
# '\nmaria is a student at a university. she likes to write poetry in her free time. her latest poem is called "the sunflower". \nshe is planning to submit it to a poetry contest, and she needs to send it to the organizers via email. \ncan you help her make some changes to the poem using string methods?\n\nhere is her contact information:\nemail: maria.poet@gmail.com\nphone number: 555-1234\n'

# %%
replace_word = make_lower.replace("sunflower", "rose")

print(replace_word)
# Out:
# maria is a student at a university. she likes to write poetry in her free time. her latest poem is called "the rose".
# she is planning to submit it to a poetry contest, and she needs to send it to the organizers via email.
# can you help her make some changes to the poem using string methods?
#
# here is her contact information:
# email: maria.poet@gmail.com
# phone number: 555-1234

# %%
def update_text(a):
  make_lower = a.lower()
  replace_word = make_lower.replace("sunflower", "rose")
  count = len(replace_word.split(" "))
  print(f"new sentence: {replace_word} || a total of word: {count}")

# %%
update_text(text)
# Out:
# new sentence:
# maria is a student at a university. she likes to write poetry in her free time. her latest poem is called "the rose".
# she is planning to submit it to a poetry contest, and she needs to send it to the organizers via email.
# can you help her make some changes to the poem using string methods?
#
# here is her contact information:
# email: maria.poet@gmail.com
# phone number: 555-1234
#  || a total of word: 64

# %%
sentence = " I am teaching python class. Replacing sunflower with rose python python python"

# %%
update_text(sentence)
# Out:
# new sentence:  i am teaching python class. replacing rose with rose || a total of word: 10

# %%
update_text(" I am teaching python class. Replacing sunflower with rose python python")
# Out:
# new sentence:  i am teaching python class. replacing rose with rose python python || a total of word: 12

# %%
words = sentence.split(" ")

# %%
count_word =[]
for word in words:
  if word =="python":
    count_word.append(word)
print(len(count_word))
# Out:
# 4

# %%
range(len(words))
# Out:
# range(0, 13)

# %%
count_word ={ "python", "java","python"}

# %%
count_word
# Out:
# {'java', 'python'}
