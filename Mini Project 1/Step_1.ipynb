# %% [markdown]
# <a href="https://colab.research.google.com/github/byambaa1982/python_cources_for_beginers/blob/tuguldur_step1/Mini%20Project%201/Step_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = '''
Maria is a student at a university. She likes to write poetry in her free time. Her latest poem is called "The Sunflower". 
She is planning to submit it to a poetry contest, and she needs to send it to the organizers via email. 
Can you help her make some changes to the poem using string methods?

Here is her contact information:
Email: maria.poet@gmail.com
Phone number: 555-1234
'''

# %% [markdown]
# ### Tasks:
#
# 1. Change all the letters in the poem to lowercase.
# 2. Replace the word "sunflower" with the word "rose".
# 3. Remove all the spaces from the poem.
# 4. Count how many times the word "love" appears in the poem.
# 5. Create a new string that includes Maria's contact information in this format:
# "Maria can be reached at maria.poet@gmail.com or 555-1234."
# 6. Create a new string that includes the first four letters of each word in the poem, capitalized. For example, "The Sunflower" would become "TSun".

# %%
text = '''
Maria is a student at a university. She likes to write poetry in her free time. Her latest poem is called "The Sunflower". 
She is planning to submit it to a poetry contest, and she needs to send it to the organizers via email. 
Can you help her make some changes to the poem using string methods?

Here is her contact information:
Email: maria.poet@gmail.com
Phone number: 555-1234
'''

text_lower = text.lower()

text_replaced = text_lower.replace("sunflower", "rose")

text_no_spaces = text_replaced.replace(" ", "")

love_count = text_lower.count("love")

contact_info = f"Maria can be reached at maria.poet@gmail.com or 555-1234."

text_capitalized = ''.join([word[:4].capitalize() for word in text.split()])

print("Task 1: Lowercase text\n", text_lower, "\n")
print("Task 2: Replace 'sunflower' with 'rose'\n", text_replaced, "\n")
print("Task 3: Remove spaces from text\n", text_no_spaces, "\n")
print("Task 4: Count 'love' occurrences\n", love_count, "\n")
print("Task 5: Contact information\n", contact_info, "\n")
print("Task 6: Capitalized first four letters of each word\n", text_capitalized, "\n")
# Out:
# Task 1: Lowercase text
#
# maria is a student at a university. she likes to write poetry in her free time. her latest poem is called "the sunflower".
# she is planning to submit it to a poetry contest, and she needs to send it to the organizers via email.
# can you help her make some changes to the poem using string methods?
#
# here is her contact information:
# email: maria.poet@gmail.com
# phone number: 555-1234
#
#
# Task 2: Replace 'sunflower' with 'rose'
#
# maria is a student at a university. she likes to write poetry in her free time. her latest poem is called "the rose".
# she is planning to submit it to a poetry contest, and she needs to send it to the organizers via email.
# can you help her make some changes to the poem using string methods?
#
# here is her contact information:
# email: maria.poet@gmail.com
# phone number: 555-1234
#
#
# Task 3: Remove spaces from text
#
# mariaisastudentatauniversity.shelikestowritepoetryinherfreetime.herlatestpoemiscalled"therose".
# sheisplanningtosubmitittoapoetrycontest,andsheneedstosendittotheorganizersviaemail.
# canyouhelphermakesomechangestothepoemusingstringmethods?
#
# hereishercontactinformation:
# email:maria.poet@gmail.com
# phonenumber:555-1234
#
#
# Task 4: Count 'love' occurrences
#  0
#
# Task 5: Contact information
#  Maria can be reached at maria.poet@gmail.com or 555-1234.
#
# Task 6: Capitalized first four letters of each word
#  MariIsAStudAtAUnivSheLikeToWritPoetInHerFreeTimeHerLatePoemIsCall"theSunfSheIsPlanToSubmItToAPoetContAndSheNeedToSendItToTheOrgaViaEmaiCanYouHelpHerMakeSomeChanToThePoemUsinStriMethHereIsHerContInfoEmaiMariPhonNumb555-
