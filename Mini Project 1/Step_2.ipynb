# %% [markdown]
# <a href="https://colab.research.google.com/github/byambaa1982/python_cources_for_beginers/blob/tuguldur_step_2/Mini%20Project%201/Step_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Task 1: split_sentence
#
# Write a Python function called `split_sentence` that takes a sentence as input and returns a list of words by splitting the sentence using the space character as the delimiter.
#
# - Input: "The manual job has failed due to null values."
# - Output: ['The', 'manual', 'job', 'has', 'failed', 'due', 'to', 'null', 'values.']

# %%
def split_sentence(sentence):
    words = sentence.split(" ")
    return words

sentence = "The manual job has failed due to null values."
word_list = split_sentence(sentence)
print(word_list)
# Out:
# ['The', 'manual', 'job', 'has', 'failed', 'due', 'to', 'null', 'values.']

# %%
def split_setence(setence): 
    words = setence.split(" ")
    return words 
setence = 'guess what she said "i wanna stay with you" just kidding, im day dreaming'
word_list = split_setence(setence)
print(word_list)
# Out:
# ['guess', 'what', 'she', 'said', '"i', 'wanna', 'stay', 'with', 'you"', 'just', 'kidding,', 'im', 'day', 'dreaming']

# %% [markdown]
# ## Task 2:
# Write a Python function called count_words that takes a list of words as input and returns the total number of words in the list.
#
# - Input: ['The', 'manual', 'job', 'has', 'failed', 'due', 'to', 'null', 'values.']
# - Output: 9

# %%
def count_words(word_list):
    return len(word_list)

words = ['The', 'manual', 'job', 'has', 'failed', 'due', 'to', 'null', 'values.']
total_words = count_words(words)
print(total_words)
# Out:
# 9

# %%
def count_words(word_list):
   return len(word_list)

words = ['guess' , 'what' , 'she' , 'said' , 'i' , 'wanna' , 'stay' , 'with' , 'you' , 'just' , 'kidding' , 'im' , 'day' , 'dreaming']
total_words = count_words(words)
print(total_words)
# Out:
# 14

# %% [markdown]
# ## Task 3: analyze_null
#
# Write a Python function called analyze_null that takes a list of words as input and checks if the word "null" is present. If it is, return its index in the list; otherwise, return -1.
#
# - Input: ['The', 'manual', 'job', 'has', 'failed', 'due', 'to', 'null', 'values.']
# - Output: 7

# %%
def analyze_null(word_list):
    if "null" in word_list:
        return word_list.index("null")
    else:
        return -1

words = ['The', 'manual', 'job', 'has', 'failed', 'due', 'to', 'null', 'values.']
result = analyze_null(words)
print(result)
# Out:
# 7

# %%
def analyze_null(word_list):
   if "null" in word_list:
       return word_list.index("nuil")
   else:
       return -1

words = ['guess' , 'what' , 'she' , 'said' , 'i' , 'wanna' , 'stay' , 'with' , 'you' , 'just' , 'kidding' , 'im' , 'day' , 'dreaming']
result = analyze_null(words)
print(result)
# Out:
# -1

# %% [markdown]
# ## Final task: Create a function
#
# Once you complete these three tasks, you can combine the functions to create the analyze_sentence function by incorporating the word count functionality and returning the analysis results as a dictionary.
#
# ```python
# # Test the function with the given sentence
# sentence = "The manual job has failed due to null values in factCompensationApproach. After further investigating, I will update you with more details."
# analysis = analyze_sentence(sentence)
#
# # Print the results
# print("Total number of words:", analysis["total_words"])
# print("Index of 'null' (if present):", analysis["null_index"])
# print("Word count:", analysis["word_count"])
#
# ```
#
#
# - Total number of words: 21
# - Index of 'null' (if present): 7
# - Word count:
# ``` python
# {'The': 1, 'manual': 1, 'job': 1, 'has': 1, 'failed': 1, 'due': 1, 'to': 1, 'null': 1, 'values': 1, 'in': 1, 'factCompensationApproach.': 1, 'After': 1, 'further': 1, 'investigating,': 1, 'I': 1, 'will': 1, 'update': 1, 'you': 1, 'with': 1, 'more': 1, 'details.': 1}
# ```

# %%
def count_words(word_list):
    word_count = {}
    for word in word_list:
        if word in word_count:
            word_count[word] += 1
        else:
            word_count[word] = 1
    return word_count

def analyze_sentence(sentence):
    words = split_sentence(sentence)
    total_words = count_words(words)
    null_index = analyze_null(words)
    return {
        "total_words": len(words),
        "null_index": null_index,
        "word_count": total_words
    }

sentence = "The manual job has failed due to null values in factCompensationApproach. After further investigating, I will update you with more details."
analysis = analyze_sentence(sentence)

print("Total number of words:", analysis["total_words"])
print("Index of 'null' (if present):", analysis["null_index"])
print("Word count:")
for word, count in analysis["word_count"].items():
    print(word + ":", count)
# Out:
# Total number of words: 21
# Index of 'null' (if present): 7
# Word count:
# The: 1
# manual: 1
# job: 1
# has: 1
# failed: 1
# due: 1
# to: 1
# null: 1
# values: 1
# in: 1
# factCompensationApproach.: 1
# After: 1
# further: 1
# investigating,: 1
# I: 1
# will: 1
# update: 1
# you: 1
# with: 1
# more: 1
# details.: 1
