# %% [markdown]
# <a href="https://colab.research.google.com/github/byambaa1982/python_cources_for_beginers/blob/class_zero_enko/Mini%20Project%201/data_modeling_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import regex as re
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
my_path = '/content/drive/MyDrive/python_class/'

# %%
df = pd.read_csv(f'{my_path}followed_users.csv')
df.head()
# Out:
#              author_id         username
# 0           1482664754  nachogarciaegea
# 1            226107083            LeVPN
# 2  1403739183861039105        kubetools
# 3  1268029174285033472         DevtronL
# 4           1713815401      CarolSobria

# %%
df.to_csv(f'{my_path}test.csv', index = False)

# %%
unfollowed= pd.read_csv(f'{my_path}unfollowed_users.csv')
unfollowed.head()
# Out:
#              author_id  followers_count    modified     record_timestamp
# 0  1170238676883820544              499  2024-08-23  2024-08-15 18:50:56
# 1            391715109              498  2024-08-23  2024-08-15 18:50:56
# 2  1214799165500248066              497  2024-08-25  2024-08-23 00:00:00
# 3   783398425383542785              496  2024-08-24  2024-08-19 00:00:00
# 4            435616284              495  2024-08-24  2024-08-22 00:00:00

# %%
detailed_users = pd.read_csv(f'{my_path}detailed_users.csv')
detailed_users
# Out:
#                        id                       name        username  \
# 0              4263007693  Dr. Ganapathi Pulipaka ??     gp_pulipaka
# 1      982283491088982016                     Prasad      rprasadgdg
# 2     1650824959202082816                  Gigged AI       Gigged_Ai
# 3     1417618100120395778                       أسما       namezzz_a
# 4     1094899950922563585          Go /data engineer       BacktestL
# ...                   ...                        ...             ...
# 4035            110526011                       Toto  toto_the_coder
# 4036           2406723812                    あぱ@次915      appappathy
# 4037            335695545    Portal Notícias do Pará  NoticiasdoPARA
# 4038  1480911691877691393                      NKuro     NKuroforevr
# 4039  1756495322652590080            Gustavo Mendoza       G30862411
#
#                     created_at  \
# 0     2015-11-17T02:19:09.000Z
# 1     2018-04-06T15:46:48.000Z
# 2     2023-04-25T11:32:04.000Z
# ...

# %% [markdown]
# # Filtering

# %%
df = pd.read_csv(f'{my_path}detailed_users.csv')
df= df[df['username'].str.contains('tool', case=False, na=False)]
df
# Out:
#                        id                   name         username  \
# 272   1403739183861039105              Kubetools        kubetools
# 862   1731298243726966784                  Rosie  SoftwareDevTool
# 890             316876277            smith jason       benedtoolz
# 1098            258868056            Ivica Delic  Free_LanceTools
# 2922           2289786481              Progtools        progtools
# 3958  1199498323096301568  tradetool@億り人 - 米国株投資       tradetool1
#
#                     created_at  \
# 272   2021-06-12T15:41:32.000Z
# 862   2023-12-03T13:04:19.000Z
# 890   2011-06-14T03:01:04.000Z
# 1098  2011-02-28T17:40:36.000Z
# 2922  2014-01-13T14:38:52.000Z
# 3958  2019-11-27T01:21:08.000Z
#
#                                             description  followers_count  \
# 272           The Future of Kubernetes Tools Discovery.             9053
# 862                                                 NaN               54
# ...

# %%
df_unfollowed = pd.read_csv(f'{my_path}unfollowed_users.csv')
df_unfollowed['modified'] = pd.to_datetime(df_unfollowed['modified'])
df_filtered = df_unfollowed[(df_unfollowed['modified'] >= '2024-08-01') & (df_unfollowed['modified'] <= '2024-08-31')]
df_filtered
# Out:
#                 author_id  followers_count   modified     record_timestamp
# 0     1170238676883820544              499 2024-08-23  2024-08-15 18:50:56
# 1               391715109              498 2024-08-23  2024-08-15 18:50:56
# 2     1214799165500248066              497 2024-08-25  2024-08-23 00:00:00
# 3      783398425383542785              496 2024-08-24  2024-08-19 00:00:00
# 4               435616284              495 2024-08-24  2024-08-22 00:00:00
# ...                   ...              ...        ...                  ...
# 1752  1521194108630577152                0 2024-08-25  2024-08-24 00:00:00
# 1753  1747005897891827712                0 2024-08-25  2024-08-24 00:00:00
# 1754  1751226564274999296                0 2024-08-25  2024-08-24 00:00:00
# 1755  1623217907109883905                0 2024-08-25  2024-08-24 00:00:00
# 1756  1606698025841311744                0 2024-08-25  2024-08-24 00:00:00
#
# [1711 rows x 4 columns]

# %%
df_with_username = df[['id', 'username']]
df_with_username
# Out:
#                        id         username
# 1      982283491088982016       rprasadgdg
# 2     1650824959202082816        Gigged_Ai
# 19    1628483562574864385       tapfornerd
# 28    1364346067467206658   freecodecampPT
# 31             1021340018     manedeepak44
# ...                   ...              ...
# 4026  1368447496423235584  Breezeandmoon88
# 4027  1545036831711932418      gabrielprdg
# 4030           3359154018  advancedsqlquer
# 4035            110526011   toto_the_coder
# 4037            335695545   NoticiasdoPARA
#
# [1657 rows x 2 columns]

# %%
df_unfollowed = pd.read_csv(f'{my_path}unfollowed_users.csv')
df_unfollowed['modified'] = pd.to_datetime(df_unfollowed['modified'])
df_filtered = df_unfollowed[(df_unfollowed['modified'] >= '2024-08-01') & (df_unfollowed['modified'] <= '2024-08-15')]
df_filtered
# Out:
#                 author_id  followers_count   modified     record_timestamp
# 16              139332711              482 2024-08-03  2024-08-15 18:50:56
# 34             1636389361              461 2024-08-06  2024-08-15 18:50:56
# 75    1185930701066997761              423 2024-08-03  2024-08-15 18:50:56
# 95    1297507948734939138              406 2024-08-08  2024-08-15 18:50:56
# 121              18402756              386 2024-08-02  2024-08-15 18:50:56
# ...                   ...              ...        ...                  ...
# 1526  1745276169740570624                0 2024-08-15  2024-08-15 18:50:56
# 1527  1745264835292528640                0 2024-08-15  2024-08-15 18:50:56
# 1528  1301818501108297728                0 2024-08-09  2024-08-15 18:50:56
# 1543  1561878223004516352                0 2024-08-09  2024-08-15 18:50:56
# 1553           3321705499                0 2024-08-09  2024-08-15 18:50:56
#
# [355 rows x 4 columns]

# %% [markdown]
# # Task 1
# - Objective: Find all users whose username starts with the letter "D".
# ## Instructions:
#  - Read the followed_users.csv file into a DataFrame.
# - Use the .str.startswith() method to filter rows where the username starts with the letter "D".
# - Display the filtered DataFrame.
# - Hint: Use the str accessor with the startswith() method to filter rows based on the first letter of the username.

# %%
df = pd.read_csv(f'{my_path}detailed_users.csv')
df= df[df['username'].str.contains('D', case=False, na=False)]
df
# Out:
#                        id                            name         username  \
# 1      982283491088982016                          Prasad       rprasadgdg
# 2     1650824959202082816                       Gigged AI        Gigged_Ai
# 19    1628483562574864385                      TapForNerd       tapfornerd
# 28    1364346067467206658  freeCodeCamp.org in Portuguese   freecodecampPT
# 31             1021340018              The Career Courier     manedeepak44
# ...                   ...                             ...              ...
# 4026  1368447496423235584             ?????????????| SxT?  Breezeandmoon88
# 4027  1545036831711932418                     gabriel.dev      gabrielprdg
# 4030           3359154018              Advanced SQL Query  advancedsqlquer
# 4035            110526011                            Toto   toto_the_coder
# 4037            335695545         Portal Notícias do Pará   NoticiasdoPARA
#
#                     created_at  \
# 1     2018-04-06T15:46:48.000Z
# ...

# %% [markdown]
# #Task 2: Filter by Description Containing a Word
# Objective: Find all rows in the unfollowed_users.csv DataFrame where the username contains the word "tool".
# #Instructions:
# Read the unfollowed_users.csv file into a DataFrame.
# Use the .str.contains() method to filter rows where the username column contains the word "tool".
# Display the filtered DataFrame.
# Hint: Use the str.contains() method with the argument 'tool' to filter rows where the username contains this word.

# %%
inner_df = pd.merge(detailed_users, df_unfol, on = 'id', how='inner')
inner_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-09eee88d9fb3> in <cell line: 1>()
# ----> 1 inner_df = pd.merge(detailed_users, df_unfol, on = 'id', how='inner')
#       2 inner_df
#
# NameError: name 'df_unfol' is not defined

# %%
df = merged_df[merged_df['username'].str.contains('bur', case=False, na=True)]
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-20a18f2e8319> in <cell line: 1>()
# ----> 1 df = merged_df[merged_df['username'].str.contains('bur', case=False, na=True)]
#       2 df
#
# NameError: name 'merged_df' is not defined

# %% [markdown]
# # Task 3: Filter by Date Range
# - Objective: Find all rows in the unfollowed_users.csv DataFrame where the modified date is in August 2024.
# ## Instructions:
# - Read the unfollowed_users.csv file into a DataFrame.
# - Convert the modified column to datetime format using pd.to_datetime().
# - Filter rows where the modified date falls between "2024-08-01" and "2024-08-31".
# - Display the filtered DataFrame.
# - Hint: Use the pd.to_datetime() method to convert the modified column to a datetime format and then filter using comparison operators.

# %%
unfol = pd.read_csv(f'{my_path}unfollowed_users.csv')
unfol['modified'] = pd.to_datetime(unfol['modified'])

# %%
filtered_df = unfol_df[(unfol_df['modified'] >= '2024-08-01') & (unfol_df['modified'] >= '2024-08-01')]
filtered_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-14be2cd11e46> in <cell line: 1>()
# ----> 1 filtered_df = unfol_df[(unfol_df['modified'] >= '2024-08-01') & (unfol_df['modified'] >= '2024-08-01')]
#       2 filtered_df
#
# NameError: name 'unfol_df' is not defined

# %% [markdown]
# # Homework: Finish Task 3.
