# %% [markdown]
# <a href="https://colab.research.google.com/github/byambaa1982/python_cources_for_beginers/blob/class_zero_burentugs/Mini%20Project%201/data_modeling_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import regex as re
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
my_path = '/content/drive/MyDrive/python_class/'

# %%
df = pd.read_csv(f'{my_path}detailed_users.csv')
df.head()
# Out:
#                     id                       name     username  \
# 0           4263007693  Dr. Ganapathi Pulipaka ??  gp_pulipaka
# 1   982283491088982016                     Prasad   rprasadgdg
# 2  1650824959202082816                  Gigged AI    Gigged_Ai
# 3  1417618100120395778                       أسما    namezzz_a
# 4  1094899950922563585          Go /data engineer    BacktestL
#
#                  created_at  \
# 0  2015-11-17T02:19:09.000Z
# 1  2018-04-06T15:46:48.000Z
# 2  2023-04-25T11:32:04.000Z
# 3  2021-07-20T22:51:24.000Z
# 4  2019-02-11T10:04:25.000Z
#
#                                          description  followers_count  \
# 0  Chief #AI Scientist | PostDoc CS, PhD | New Yo...           180209
# 1                                                  ?              119
# 2  The skills-based Talent Marketplace solving th...              318
# 3  Software Engineer at @glovo #Coding #Cinema #B...              590
# ...

# %% [markdown]
# # Filtering

# %% [markdown]
# # Task 1
# 1. Create a CSV file named "active_users" with the following columns: id, name, and tweet_count.
# ## Instructions:
# - Use the pandas library to create a DataFrame from the given data.
# - Select only the id, name, and tweet_count columns.
# - Save this selection as a CSV file named active_users.csv.

# %%
detailed_df = df[['id', 'name', 'tweet_count']]
detailed_df
# Out:
#                        id                       name  tweet_count
# 0              4263007693  Dr. Ganapathi Pulipaka ??        89924
# 1      982283491088982016                     Prasad         1875
# 2     1650824959202082816                  Gigged AI          174
# 3     1417618100120395778                       أسما         6659
# 4     1094899950922563585          Go /data engineer         1400
# ...                   ...                        ...          ...
# 4035            110526011                       Toto         6575
# 4036           2406723812                    あぱ@次915        51742
# 4037            335695545    Portal Notícias do Pará        49969
# 4038  1480911691877691393                      NKuro         5532
# 4039  1756495322652590080            Gustavo Mendoza            1
#
# [4040 rows x 3 columns]

# %%
detailed_df.to_csv('active_users.csv', index=True)

# %% [markdown]
# # Task 2: Filter by Description Containing a Word
# - Print how many users have tweeted more than:
#
# - 1000 times
# - 2000 times
# - 3000 times
# ## Instructions:
# - Use the pandas DataFrame to filter users who have tweeted more than 1000, 2000, and 3000 times.
# - Print the count of users for each category.

# %%
filtered_df = df[df['tweet_count']>1000]
print(filtered_df.shape)
# Out:
# (2564, 10)

# %%
filtered_df = df[df['tweet_count']>2000]
print(filtered_df.shape)
# Out:
# (2210, 10)

# %%
filtered_df = df[df['tweet_count']>3000]
print(filtered_df.shape)
# Out:
# (1989, 10)

# %% [markdown]
# # Task 3: Filter by Date Range
# 1. Create a CSV file named "engineers" with the following columns: id, name, and tweet_count.
# ## Instructions:
# - Use the pandas library to create a DataFrame from the given data.
# - Select only the id, name, and tweet_count columns.
# - Save this selection as a CSV file named engineers.csv.

# %%
engineer_df = df[df['name'].str.contains('engineer', case=False, na=False)]
engineer_df
# Out:
#                        id                                             name  \
# 4     1094899950922563585                                Go /data engineer
# 222   1662557232226091009                                    Data Engineer
# 443   1195818915030540290           EchoJobs | Best Software Engineer Jobs
# 481            4375073113                                 Bigdata Engineer
# 520   1406639376675770374                  Dan | Machine Learning Engineer
# 666             137199262                                    Engineer John
# 818   1444892661156962304                                 Average Engineer
# 879             320105897                      Darshil | Data Engineer??‍?
# 946   1743042524304785411                            Cloud Native Engineer
# 1042             35827832                                  Engineering.com
# 1252  1089703926373462026                           Omni Data Engineer Kai
# ...

# %%
filtered_engi_df = engineer_df[['id', 'name', 'tweet_count', 'followers_count']]
filtered_engi_df
# Out:
#                        id                                             name  \
# 4     1094899950922563585                                Go /data engineer
# 222   1662557232226091009                                    Data Engineer
# 443   1195818915030540290           EchoJobs | Best Software Engineer Jobs
# 481            4375073113                                 Bigdata Engineer
# 520   1406639376675770374                  Dan | Machine Learning Engineer
# 666             137199262                                    Engineer John
# 818   1444892661156962304                                 Average Engineer
# 879             320105897                      Darshil | Data Engineer??‍?
# 946   1743042524304785411                            Cloud Native Engineer
# 1042             35827832                                  Engineering.com
# 1252  1089703926373462026                           Omni Data Engineer Kai
# ...

# %%
filtered_engi_df.to_csv('engineers.csv', index=False)

# %% [markdown]
# # Task 4:
# 1. Read the engineers.csv file and the detailed_users.csv file.
# 2. Join these two files based on a common column, and include the followers_count column in the result. The ouput columns are id, name, tweet_count, and followers_count
# ## Instructions:
# 1. Read the two CSV files using pandas.
# 2. Merge the DataFrames on a common column (e.g., id).
# 3. Include the followers_count column from detailed_users.csv in the final DataFrame.

# %%
engi = pd.read_csv('engineers.csv')
engi
# Out:
#                      id                                             name  \
# 0   1094899950922563585                                Go /data engineer
# 1   1662557232226091009                                    Data Engineer
# 2   1195818915030540290           EchoJobs | Best Software Engineer Jobs
# 3            4375073113                                 Bigdata Engineer
# 4   1406639376675770374                  Dan | Machine Learning Engineer
# 5             137199262                                    Engineer John
# 6   1444892661156962304                                 Average Engineer
# 7             320105897                      Darshil | Data Engineer??‍?
# 8   1743042524304785411                            Cloud Native Engineer
# 9              35827832                                  Engineering.com
# 10  1089703926373462026                           Omni Data Engineer Kai
# 11  1736801714450444291                   Preet Desai | Data Engineer?‍?
# ...

# %%
detailed = pd.read_csv('detailed_users.csv')
detailed
# Out:
#                        id                       name        username  \
# 0              4263007693  Dr. Ganapathi Pulipaka ??     gp_pulipaka
# 1      982283491088982016                     Prasad      rprasadgdg
# 2     1650824959202082816                  Gigged AI       Gigged_Ai
# 3     1417618100120395778                       أسما       namezzz_a
# 4     1094899950922563585          Go /data engineer       BacktestL
# ...                   ...                        ...             ...
# 4035            110526011                       Toto  toto_the_coder
# 4036           2406723812                    あぱ@次915      appappathy
# 4037            335695545    Portal Notícias do Pará  NoticiasdoPARA
# 4038  1480911691877691393                      NKuro     NKuroforevr
# 4039  1756495322652590080            Gustavo Mendoza       G30862411
#
#                     created_at  \
# 0     2015-11-17T02:19:09.000Z
# 1     2018-04-06T15:46:48.000Z
# 2     2023-04-25T11:32:04.000Z
# ...

# %%
merged_df = pd.merge(engi, detailed[['id', 'followers_count']], on='id', how='left')
merged_df
# Out:
#                      id                                             name  \
# 0   1094899950922563585                                Go /data engineer
# 1   1662557232226091009                                    Data Engineer
# 2   1195818915030540290           EchoJobs | Best Software Engineer Jobs
# 3            4375073113                                 Bigdata Engineer
# 4   1406639376675770374                  Dan | Machine Learning Engineer
# 5             137199262                                    Engineer John
# 6   1444892661156962304                                 Average Engineer
# 7             320105897                      Darshil | Data Engineer??‍?
# 8   1743042524304785411                            Cloud Native Engineer
# 9              35827832                                  Engineering.com
# 10  1089703926373462026                           Omni Data Engineer Kai
# 11  1736801714450444291                   Preet Desai | Data Engineer?‍?
# ...

# %% [markdown]
# # Homework 1: Filter Users with High Followers Count
# Objective: Filter and display users who have more than 500 followers.
#
# ## Instructions:
# - Use the merged DataFrame from Task 3.
# - Filter the users who have more than 500 followers in the followers_count column.
# - Print the filtered DataFrame.

# %%
filtered_df = engineer_df[df['followers_count']>500]
filtered_df
# Out:
# <ipython-input-17-dea7f76ecb5a>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered_df = engineer_df[df['followers_count']>500]
#                        id                                    name  \
# 222   1662557232226091009                           Data Engineer
# 443   1195818915030540290  EchoJobs | Best Software Engineer Jobs
# 481            4375073113                        Bigdata Engineer
# 520   1406639376675770374         Dan | Machine Learning Engineer
# 666             137199262                           Engineer John
# 818   1444892661156962304                        Average Engineer
# 879             320105897             Darshil | Data Engineer??‍?
# 1042             35827832                         Engineering.com
# 1252  1089703926373462026                  Omni Data Engineer Kai
# 3271  1391866795053682696             Senior Spreadsheet Engineer
#
#              username                created_at  \
# ...

# %% [markdown]
# # Homework 2: Calculate the Average Tweet Count per User
# Objective: Calculate and print the average tweet count of users in the detailed_users.csv file.
#
# ## Instructions:
# - Read the detailed_users.csv file again if not already loaded.
# - Calculate the average of the tweet_count column.
# - Print the average tweet count.

# %%
pd.read_csv('detailed_users.csv')
# Out:
#                        id                       name        username  \
# 0              4263007693  Dr. Ganapathi Pulipaka ??     gp_pulipaka
# 1      982283491088982016                     Prasad      rprasadgdg
# 2     1650824959202082816                  Gigged AI       Gigged_Ai
# 3     1417618100120395778                       أسما       namezzz_a
# 4     1094899950922563585          Go /data engineer       BacktestL
# ...                   ...                        ...             ...
# 4035            110526011                       Toto  toto_the_coder
# 4036           2406723812                    あぱ@次915      appappathy
# 4037            335695545    Portal Notícias do Pará  NoticiasdoPARA
# 4038  1480911691877691393                      NKuro     NKuroforevr
# 4039  1756495322652590080            Gustavo Mendoza       G30862411
#
#                     created_at  \
# 0     2015-11-17T02:19:09.000Z
# 1     2018-04-06T15:46:48.000Z
# 2     2023-04-25T11:32:04.000Z
# ...

# %%
average_tweet_count = df['tweet_count'].mean()

# %%
print(f"The average tweet count is: {average_tweet_count}")
# Out:
# The average tweet count is: 18160.071534653467
