# %% [markdown]
# <a href="https://colab.research.google.com/github/byambaa1982/python_cources_for_beginers/blob/class_zero_burentugs/Mini%20Project%201/data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import regex as re
import os

# %% [markdown]
# # Data Cleaning and Preprocessing:
# 0. Data Cleaning
# - Task: Clean the description column to remove special characters, emojis, or unwanted text.
# - Skill: Learn how to clean text data using pandas and Python string methods.
# 1. Filtering and Querying Data:
#
# - Task: Find users with more than 10,000 followers and less than 500 following.
# - Skill: Teach how to filter DataFrames based on multiple conditions.
# 2. Date and Time Handling:
#
# - Task: Extract the year from the created_at column and find how many users joined each year.
# - Skill: Learn how to handle date and time data using pandas.
# 3. Data Aggregation and Grouping:
#
# - Task: Group users by the year they joined and calculate the average number of followers per year.
# - Skill: Learn grouping and aggregation techniques to summarize data.
# 4. Text Analysis:
#
# - Task: Count how many users have descriptions containing specific keywords like "Engineer," "AI," or "Data."
# - Skill: Basic natural language processing (NLP) techniques using pandas to analyze text data.
# 5. Data Visualization:
#
# - Task: Create a bar chart showing the number of users who joined each year.
# - Skill: Learn to visualize data trends using libraries like Matplotlib or Seaborn.
# 6. Correlation Analysis:
#
# - Task: Calculate the correlation between followers_count and following_count to see if more followers relate to higher following counts.
# - Skill: Teach how to analyze relationships between numerical data.
# 7. Statistical Analysis:
#
# - Task: Find the median, mean, and standard deviation of the tweet_count column.
# - Skill: Basic statistical analysis with pandas to understand the spread and central tendency of data.
# 8. Data Merging and Joining:
#
# - Task: Merge this dataset with another table (like profiles) to find additional insights such as missing descriptions.
# - Skill: Learn how to merge DataFrames based on keys using merge().
# 9. Handling Missing Data:
#
# - Task: Identify and fill missing values in the description column with a default message.
# - Skill: Techniques for dealing with missing or incomplete data using pandas.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
my_path = '/content/drive/MyDrive/python_class/'

# %%
df = pd.read_csv(f'{my_path}detailed_users.csv')
df.head()
# Out:
#                     id                       name     username  \
# 0           4263007693  Dr. Ganapathi Pulipaka ??  gp_pulipaka
# 1   982283491088982016                     Prasad   rprasadgdg
# 2  1650824959202082816                  Gigged AI    Gigged_Ai
# 3  1417618100120395778                       أسما    namezzz_a
# 4  1094899950922563585          Go /data engineer    BacktestL
#
#                  created_at  \
# 0  2015-11-17T02:19:09.000Z
# 1  2018-04-06T15:46:48.000Z
# 2  2023-04-25T11:32:04.000Z
# 3  2021-07-20T22:51:24.000Z
# 4  2019-02-11T10:04:25.000Z
#
#                                          description  followers_count  \
# 0  Chief #AI Scientist | PostDoc CS, PhD | New Yo...           180209
# 1                                                  ?              119
# 2  The skills-based Talent Marketplace solving th...              318
# 3  Software Engineer at @glovo #Coding #Cinema #B...              590
# ...

# %%
users = pd.read_csv(f'{my_path}profiles_output.csv')
display(users)
# Out:
#                                           name          username  follows_me  \
# 0                                 Hoang Nguyen          @cuber_x       False
# 1                                     GetBundi         @GetBundi       False
# 2                                     doughboy      @far__away__       False
# 3                                   Daniel Han    @danielhanchen       False
# 4                                       marimo        @marimo_io       False
# ...                                        ...               ...         ...
# 1101  Shriram Krishnamurthi 🟤 🏴‍☠️ 👨🏽‍🏫 🚴‍♂️ 🏏   @ShriramKMurthi       False
# 1102                                         /  @BrownUniversity       False
# 1103                                         •        @PyretLang       False
# 1104                           Akande Damilola       @Haryanfe__       False
# 1105                                  Ryan Els         @RyanEls4       False
#
# ...

# %% [markdown]
# # Filtering

# %% [markdown]
# # Clean Usernames and Join with Detailed Users
# - Objective:
#
# - Read the profiles_output.csv file, clean the username column by removing all "@" symbols, and join it with the detailed_users.csv file on the username column.
# - Calculate how many users are present in both tables.
# ## Instructions:
# - Read the profiles_output.csv file using pandas and display the DataFrame.
# - Clean the username column by removing all "@" symbols.
# - Read the detailed_users.csv file.
# - Join the two DataFrames on the username column.
# - Count how many users are present in both tables after the join.

# %% [markdown]
# Task #1

# %%
detailed_df = pd.read_csv(f'{my_path}detailed_users.csv')
detailed_df
# Out:
#                        id                       name        username  \
# 0              4263007693  Dr. Ganapathi Pulipaka ??     gp_pulipaka
# 1      982283491088982016                     Prasad      rprasadgdg
# 2     1650824959202082816                  Gigged AI       Gigged_Ai
# 3     1417618100120395778                       أسما       namezzz_a
# 4     1094899950922563585          Go /data engineer       BacktestL
# ...                   ...                        ...             ...
# 4035            110526011                       Toto  toto_the_coder
# 4036           2406723812                    あぱ@次915      appappathy
# 4037            335695545    Portal Notícias do Pará  NoticiasdoPARA
# 4038  1480911691877691393                      NKuro     NKuroforevr
# 4039  1756495322652590080            Gustavo Mendoza       G30862411
#
#                     created_at  \
# 0     2015-11-17T02:19:09.000Z
# 1     2018-04-06T15:46:48.000Z
# 2     2023-04-25T11:32:04.000Z
# ...

# %%
detailed_df['username'] = detailed_df['username'].str.replace('@', '', regex=True)
detailed_df
# Out:
#                        id                       name        username  \
# 0              4263007693  Dr. Ganapathi Pulipaka ??     gp_pulipaka
# 1      982283491088982016                     Prasad      rprasadgdg
# 2     1650824959202082816                  Gigged AI       Gigged_Ai
# 3     1417618100120395778                       أسما       namezzz_a
# 4     1094899950922563585          Go /data engineer       BacktestL
# ...                   ...                        ...             ...
# 4035            110526011                       Toto  toto_the_coder
# 4036           2406723812                    あぱ@次915      appappathy
# 4037            335695545    Portal Notícias do Pará  NoticiasdoPARA
# 4038  1480911691877691393                      NKuro     NKuroforevr
# 4039  1756495322652590080            Gustavo Mendoza       G30862411
#
#                     created_at  \
# 0     2015-11-17T02:19:09.000Z
# 1     2018-04-06T15:46:48.000Z
# 2     2023-04-25T11:32:04.000Z
# ...

# %% [markdown]
# Task #2

# %%
deatailed_df = df[(df['followers_count'] > 10000) & (df['following_count'] < 500)]
print(detailed_df)
# Out:
#                        id                       name        username  \
# 0              4263007693  Dr. Ganapathi Pulipaka ??     gp_pulipaka
# 1      982283491088982016                     Prasad      rprasadgdg
# 2     1650824959202082816                  Gigged AI       Gigged_Ai
# 3     1417618100120395778                       أسما       namezzz_a
# 4     1094899950922563585          Go /data engineer       BacktestL
# ...                   ...                        ...             ...
# 4035            110526011                       Toto  toto_the_coder
# 4036           2406723812                    あぱ@次915      appappathy
# 4037            335695545    Portal Notícias do Pará  NoticiasdoPARA
# 4038  1480911691877691393                      NKuro     NKuroforevr
# 4039  1756495322652590080            Gustavo Mendoza       G30862411
#
#                     created_at  \
# 0     2015-11-17T02:19:09.000Z
# 1     2018-04-06T15:46:48.000Z
# 2     2023-04-25T11:32:04.000Z
# ...

# %% [markdown]
# Task #3

# %%
detailed_df = users[(users >= 2024-08-01) & (users <= 2024-08-31)]
detailed_df
# Out:
#   File "<ipython-input-17-304a9bfb8149>", line 1
#     detailed_df = users[(users >= 2024-08-01) & (users <= 2024-08-31)]
#                                        ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %% [markdown]
# Task #4

# %%
avg_followers_per_year = df.groupby('record_timestamp')['followers_count'].mean()
print(avg_followers_per_year)
# Out:
# record_timestamp
# 2024-08-15 18:50:56    17495.644269
# 2024-08-15 18:55:06      125.000000
# 2024-08-17 00:00:00      990.088889
# 2024-08-18 00:00:00     5066.495000
# 2024-08-19 00:00:00    18260.145000
# 2024-08-20 00:00:00    14029.650000
# 2024-08-21 00:00:00     7002.610000
# 2024-08-22 00:00:00     3819.855000
# 2024-08-23 00:00:00     3738.881579
# 2024-08-24 00:00:00     4598.783784
# 2024-08-25 00:00:00    10608.795000
# 2024-08-26 00:00:00     3789.440000
# 2024-08-27 00:00:00     3253.675000
# 2024-08-28 00:00:00     7768.745562
# Name: followers_count, dtype: float64

# %% [markdown]
# Task #5

# %% [markdown]
# Task #6

# %% [markdown]
# Task #7

# %% [markdown]
# Task #8

# %%
correlation = df['followers_count'].corr(df['following_count'])
print(correlation)
# Out:
# 0.03192399497726636

# %% [markdown]
# Task #9

# %%
median = df['tweet_count'].median()
mean = df['tweet_count'].mean()
std_dev = df['tweet_count'].std()

print(f'Median: {median}, Mean: {mean}, Std Dev: {std_dev}')
# Out:
# Median: 2840.5, Mean: 18160.071534653467, Std Dev: 70974.85526547077

# %% [markdown]
# Task #10

# %%
merged_df = pd.merge(detailed_df, users, on='username', how='left')
print(merged_df)
# Out:
#                        id                     name_x        username  \
# 0              4263007693  Dr. Ganapathi Pulipaka ??     gp_pulipaka
# 1      982283491088982016                     Prasad      rprasadgdg
# 2     1650824959202082816                  Gigged AI       Gigged_Ai
# 3     1417618100120395778                       أسما       namezzz_a
# 4     1094899950922563585          Go /data engineer       BacktestL
# ...                   ...                        ...             ...
# 4035            110526011                       Toto  toto_the_coder
# 4036           2406723812                    あぱ@次915      appappathy
# 4037            335695545    Portal Notícias do Pará  NoticiasdoPARA
# 4038  1480911691877691393                      NKuro     NKuroforevr
# 4039  1756495322652590080            Gustavo Mendoza       G30862411
#
#                     created_at  \
# 0     2015-11-17T02:19:09.000Z
# 1     2018-04-06T15:46:48.000Z
# 2     2023-04-25T11:32:04.000Z
# ...
