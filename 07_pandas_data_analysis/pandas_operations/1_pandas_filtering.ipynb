# %% [markdown]
# <a href="https://colab.research.google.com/github/byambaa1982/python_cources_for_beginers/blob/main/Mini%20Project%201/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Back End
# - Python : pandas
# - SQL
#
# ## Front End
# - HTML
# - CSV

# %%
import pandas as pd

# Create a DataFrame with 10 rows
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Ella', 'Frank', 'Grace', 'Hannah', 'Ian', 'Jack'],
    'Favorite Animal': ['Panda', 'Elephant', 'Giraffe', 'Panda', 'Koala', 'Lion', 'Dolphin', 'Panda', 'Tiger', 'Penguin'],
    'Age': [10, 12, 11, 10, 9, 13, 11, 10, 12, 9],
    'Score': [85, 92, 88, 76, 95, 89, 91, 87, 84, 90],
    'Favorite Color': ['Red', 'Blue', 'Green', 'Yellow', 'Purple', 'Orange', 'Pink', 'Teal', 'Brown', 'Black']
}

df = pd.DataFrame(data)

df
# Out:
#       Name Favorite Animal  Age  Score Favorite Color
# 0    Alice           Panda   10     85            Red
# 1      Bob        Elephant   12     92           Blue
# 2  Charlie         Giraffe   11     88          Green
# 3    David           Panda   10     76         Yellow
# 4     Ella           Koala    9     95         Purple
# 5    Frank            Lion   13     89         Orange
# 6    Grace         Dolphin   11     91           Pink
# 7   Hannah           Panda   10     87           Teal
# 8      Ian           Tiger   12     84          Brown
# 9     Jack         Penguin    9     90          Black

# %%
df[df['Age']==10]
# Out:
#      Name Favorite Animal  Age  Score Favorite Color
# 0   Alice           Panda   10     85            Red
# 3   David           Panda   10     76         Yellow
# 7  Hannah           Panda   10     87           Teal

# %%
df[(df['Age']>=10) & (df['Age']<=11)]
# Out:
#       Name Favorite Animal  Age  Score Favorite Color
# 0    Alice           Panda   10     85            Red
# 2  Charlie         Giraffe   11     88          Green
# 3    David           Panda   10     76         Yellow
# 6    Grace         Dolphin   11     91           Pink
# 7   Hannah           Panda   10     87           Teal

# %%
df[["Name", "Age", "Score"]]
# Out:
#       Name  Age  Score
# 0    Alice   10     85
# 1      Bob   12     92
# 2  Charlie   11     88
# 3    David   10     76
# 4     Ella    9     95
# 5    Frank   13     89
# 6    Grace   11     91
# 7   Hannah   10     87
# 8      Ian   12     84
# 9     Jack    9     90

# %%
name_age_score = df[["Name", "Age", "Score"]]

# %%
name_age_score
# Out:
#       Name  Age  Score
# 0    Alice   10     85
# 1      Bob   12     92
# 2  Charlie   11     88
# 3    David   10     76
# 4     Ella    9     95
# 5    Frank   13     89
# 6    Grace   11     91
# 7   Hannah   10     87
# 8      Ian   12     84
# 9     Jack    9     90

# %%
average_score = df['Score'].mean()
print(f"The average score is {average_score}")
max_score = df['Score'].max()
print(f"The max score is {max_score}")
minimum_score = df['Score'].min()
print(f"The minimum score is {minimum_score}")
# Out:
# The average score is 87.7
# The max score is 95
# The minimum score is 76

# %%
df_sorted = df.sort_values(by= "Score")
df_sorted
# Out:
#       Name Favorite Animal  Age  Score Favorite Color
# 3    David           Panda   10     76         Yellow
# 8      Ian           Tiger   12     84          Brown
# 0    Alice           Panda   10     85            Red
# 7   Hannah           Panda   10     87           Teal
# 2  Charlie         Giraffe   11     88          Green
# 5    Frank            Lion   13     89         Orange
# 9     Jack         Penguin    9     90          Black
# 6    Grace         Dolphin   11     91           Pink
# 1      Bob        Elephant   12     92           Blue
# 4     Ella           Koala    9     95         Purple

# %%
def find_average(col):
  average_score = df[col].mean()
  print(f"The average {col} is {average_score}")

# %%
find_average('Age')
# Out:
# The average Age is 10.7

# %%
find_average('Score')
# Out:
# The average Score is 87.7

# %% [markdown]
# # Homework

# %% [markdown]
# Create a DataFrame
#
# 1. Create a DataFrame with the following data:
#
#
# | Name   | Age | Favorite Subject | Grade |
# |--------|-----|------------------|-------|
# | Emma   | 10  | Math             | 85    |
# | Oliver | 12  | Science          | 90    |
# | Ava    | 11  | History          | 88    |
# | Lucas  | 10  | English          | 92    |
# | Mia    | 12  | Art              | 95    |
#
#
# 2. Print the entire DataFrame to see all the data.
#
#
# 3. Print only the "Name" and "Favorite Subject" columns.
#
#
# 4. Calculate and print the average grade of all the students.
#
# 5. Create a new DataFrame that only includes students with a grade higher than 90.
#
# 6. Sort the original DataFrame by the "Age" column in ascending order and print the sorted DataFrame.
# 7. Bonus Challenge (Optional)
#
# Find the student with the highest grade and print their name and grade.
