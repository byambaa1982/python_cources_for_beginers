# %% [markdown]
# <a href="https://colab.research.google.com/github/byambaa1982/python_cources_for_beginers/blob/main/Mini%20Project%201/data_modeling_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import regex as re
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
my_path = '/content/drive/MyDrive/python_class/'

# %%
df = pd.read_csv(f'{my_path}followed_users.csv')
df.head()
# Out:
#              author_id         username
# 0           1482664754  nachogarciaegea
# 1            226107083            LeVPN
# 2  1403739183861039105        kubetools
# 3  1268029174285033472         DevtronL
# 4           1713815401      CarolSobria

# %%
df.to_csv(f'{my_path}test.csv', index = False)

# %%
unfollowed= pd.read_csv(f'{my_path}unfollowed_users.csv')
unfollowed.head()
# Out:
#              author_id  followers_count    modified     record_timestamp
# 0  1170238676883820544              499  2024-08-23  2024-08-15 18:50:56
# 1            391715109              498  2024-08-23  2024-08-15 18:50:56
# 2  1214799165500248066              497  2024-08-25  2024-08-23 00:00:00
# 3   783398425383542785              496  2024-08-24  2024-08-19 00:00:00
# 4            435616284              495  2024-08-24  2024-08-22 00:00:00

# %%
df = pd.read_csv(f'{my_path}detailed_users.csv')
df.head()
# Out:
#                     id                       name     username  \
# 0           4263007693  Dr. Ganapathi Pulipaka ??  gp_pulipaka
# 1   982283491088982016                     Prasad   rprasadgdg
# 2  1650824959202082816                  Gigged AI    Gigged_Ai
# 3  1417618100120395778                       أسما    namezzz_a
# 4  1094899950922563585          Go /data engineer    BacktestL
#
#                  created_at  \
# 0  2015-11-17T02:19:09.000Z
# 1  2018-04-06T15:46:48.000Z
# 2  2023-04-25T11:32:04.000Z
# 3  2021-07-20T22:51:24.000Z
# 4  2019-02-11T10:04:25.000Z
#
#                                          description  followers_count  \
# 0  Chief #AI Scientist | PostDoc CS, PhD | New Yo...           180209
# 1                                                  ?              119
# 2  The skills-based Talent Marketplace solving th...              318
# 3  Software Engineer at @glovo #Coding #Cinema #B...              590
# ...

# %% [markdown]
# # 1. Filter and Save Specific Rows:
# - From the detailed_users.csv, filter users with a followers_count less than 200. Save this filtered DataFrame to a new CSV file named unpopular_users.csv.
#
# # 2. Merge DataFrames on Common Column
# - Objective: Merge the two DataFrames detailed_users.csv and unfollowed_users.csv on the common column author_id.
# ## Instructions:
# - Read both CSV files into separate DataFrames.
# - Perform an inner merge on the author_id column to create a DataFrame containing only users present in both files.
# - Display the first few rows of the merged DataFrame.
#
# # 3. Merge DataFrames with Different Join Types
# - Objective: Explore different types of merges (inner, outer, left, right) using the two DataFrames.
# ## Instructions:
# - Perform an outer merge to include all users, regardless of whether they are in detailed_users.csv or unfollowed_users.csv.
# - Perform a left merge to include all users from detailed_users.csv and only those from unfollowed_users.csv that have matching author_id.
# - Display the first few rows of each merged DataFrame.

# %%
detailed_users = pd.read_csv('detailed_users.csv')
detailed_users.head()
# Out:
#                     id                       name     username  \
# 0           4263007693  Dr. Ganapathi Pulipaka ??  gp_pulipaka
# 1   982283491088982016                     Prasad   rprasadgdg
# 2  1650824959202082816                  Gigged AI    Gigged_Ai
# 3  1417618100120395778                       أسما    namezzz_a
# 4  1094899950922563585          Go /data engineer    BacktestL
#
#                  created_at  \
# 0  2015-11-17T02:19:09.000Z
# 1  2018-04-06T15:46:48.000Z
# 2  2023-04-25T11:32:04.000Z
# 3  2021-07-20T22:51:24.000Z
# 4  2019-02-11T10:04:25.000Z
#
#                                          description  followers_count  \
# 0  Chief #AI Scientist | PostDoc CS, PhD | New Yo...           180209
# 1                                                  ?              119
# 2  The skills-based Talent Marketplace solving th...              318
# 3  Software Engineer at @glovo #Coding #Cinema #B...              590
# ...

# %%
unfol = pd.read_csv('/content/drive/MyDrive/python_class/unfollowed_users.csv')
unfol.head()
# Out:
#              author_id  followers_count    modified     record_timestamp
# 0  1170238676883820544              499  2024-08-23  2024-08-15 18:50:56
# 1            391715109              498  2024-08-23  2024-08-15 18:50:56
# 2  1214799165500248066              497  2024-08-25  2024-08-23 00:00:00
# 3   783398425383542785              496  2024-08-24  2024-08-19 00:00:00
# 4            435616284              495  2024-08-24  2024-08-22 00:00:00

# %%
mergedDF = pd.merge(unfol, detailed_users, left_on='author_id', right_on='id', how='left')
mergedDF
# Out:
#                 author_id  followers_count_x    modified   record_timestamp_x  \
# 0     1170238676883820544                499  2024-08-23  2024-08-15 18:50:56
# 1               391715109                498  2024-08-23  2024-08-15 18:50:56
# 2     1214799165500248066                497  2024-08-25  2024-08-23 00:00:00
# 3      783398425383542785                496  2024-08-24  2024-08-19 00:00:00
# 4               435616284                495  2024-08-24  2024-08-22 00:00:00
# ...                   ...                ...         ...                  ...
# 1752  1521194108630577152                  0  2024-08-25  2024-08-24 00:00:00
# 1753  1747005897891827712                  0  2024-08-25  2024-08-24 00:00:00
# 1754  1751226564274999296                  0  2024-08-25  2024-08-24 00:00:00
# 1755  1623217907109883905                  0  2024-08-25  2024-08-24 00:00:00
# 1756  1606698025841311744                  0  2024-08-25  2024-08-24 00:00:00
#
# ...

# %%
unfol = unfol.rename(columns = {'author_id': 'id'})
unfol.head()
# Out:
#                     id  followers_count    modified     record_timestamp
# 0  1170238676883820544              499  2024-08-23  2024-08-15 18:50:56
# 1            391715109              498  2024-08-23  2024-08-15 18:50:56
# 2  1214799165500248066              497  2024-08-25  2024-08-23 00:00:00
# 3   783398425383542785              496  2024-08-24  2024-08-19 00:00:00
# 4            435616284              495  2024-08-24  2024-08-22 00:00:00

# %%
mergedDF = pd.merge(unfol, detailed_users, on = 'id', how='left')
mergedDF
# Out:
#                        id  followers_count_x    modified   record_timestamp_x  \
# 0     1170238676883820544                499  2024-08-23  2024-08-15 18:50:56
# 1               391715109                498  2024-08-23  2024-08-15 18:50:56
# 2     1214799165500248066                497  2024-08-25  2024-08-23 00:00:00
# 3      783398425383542785                496  2024-08-24  2024-08-19 00:00:00
# 4               435616284                495  2024-08-24  2024-08-22 00:00:00
# ...                   ...                ...         ...                  ...
# 1752  1521194108630577152                  0  2024-08-25  2024-08-24 00:00:00
# 1753  1747005897891827712                  0  2024-08-25  2024-08-24 00:00:00
# 1754  1751226564274999296                  0  2024-08-25  2024-08-24 00:00:00
# 1755  1623217907109883905                  0  2024-08-25  2024-08-24 00:00:00
# 1756  1606698025841311744                  0  2024-08-25  2024-08-24 00:00:00
#
# ...

# %% [markdown]
# # Homework: Finish Task 3.
