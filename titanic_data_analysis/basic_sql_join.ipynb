# %% [markdown]
# <a href="https://colab.research.google.com/github/byambaa1982/python_cources_for_beginers/blob/class_zero_burentugs/titanic_data_analysis/basic_sql_join.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlite3

# %% [markdown]
# # SQL
#
# - Step 1. Download titanic.sqlite
#
# - step 2. Upload file into notebook
#
# - step 3. Run the first two cells

# %%
# Connect to the SQLite database
conn = sqlite3.connect('titanic.sqlite')

# Read the 'titanic' table into a pandas DataFrame
df = pd.read_sql('SELECT * FROM titanic', conn)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Use 'PassengerId', 'Name', 'Sex', 'Age' columns and save dataframe into database as passenger_info

# %%
# 1. Passenger Info Table
passenger_info = df[['PassengerId', 'Name', 'Sex', 'Age']]
passenger_info.to_sql('passenger_info', conn, if_exists='replace', index=False)

# 2. Ticket Info Table
ticket_info = df[['PassengerId', 'Ticket', 'Fare', 'Pclass']]
ticket_info.to_sql('ticket_info', conn, if_exists='replace', index=False)

# 3. Survival Status Table
survival_status = df[['PassengerId', 'Survived', 'Parch', 'SibSp']]
survival_status.to_sql('survival_status', conn, if_exists='replace', index=False)
# Out:
# 891

# %%
tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table'", conn)
print(tables)
# Out:
#               name
# 0          titanic
# 1   passenger_info
# 2      ticket_info
# 3  survival_status

# %%
q = '''
select PassengerId, Name from passenger_info limit 5
'''
p_info = pd.read_sql(q, conn)
p_info
# Out:
#    PassengerId                                               Name
# 0            1                            Braund, Mr. Owen Harris
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3                             Heikkinen, Miss. Laina
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5                           Allen, Mr. William Henry

# %%
q = """
SELECT
    passenger_info.PassengerId,
    passenger_info.Name,
    ticket_info.Ticket
FROM
    passenger_info
JOIN
    ticket_info
ON
    passenger_info.PassengerId = ticket_info.PassengerId;
"""

df = pd.read_sql_query(q, conn)

df
# Out:
#      PassengerId                                               Name  \
# 0              1                            Braund, Mr. Owen Harris
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3                             Heikkinen, Miss. Laina
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5                           Allen, Mr. William Henry
# ..           ...                                                ...
# 886          887                              Montvila, Rev. Juozas
# 887          888                       Graham, Miss. Margaret Edith
# 888          889           Johnston, Miss. Catherine Helen "Carrie"
# 889          890                              Behr, Mr. Karl Howell
# 890          891                                Dooley, Mr. Patrick
#
#                Ticket
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# ...

# %%
my_query = '''

SELECT
    passenger_info.PassengerId,
    Name,
    Sex,
    Age,
    Ticket,
    Fare,
    Pclass,
    Survived,
    Parch,
    SibSp
FROM
    passenger_info
JOIN
    ticket_info
ON
    passenger_info.PassengerId = ticket_info.PassengerId
JOIN
    survival_status
ON
    passenger_info.PassengerId = survival_status.PassengerId;

'''

# %%
df = pd.read_sql(my_query, conn)

df
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
# ...

# %%
q = """
select
  passenger_info.PassengerId,
  passenger_info.Name,
  survival_status.Survived
from
  passenger_info
join
  survival_status
on
  passenger_info.PassengerId = survival_status.PassengerId
where
  Survived = 1;
"""
df = pd.read_sql(q, conn)
df
# Out:
#      PassengerId                                               Name  Survived
# 0              2  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 1              3                             Heikkinen, Miss. Laina         1
# 2              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 3              9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1
# 4             10                Nasser, Mrs. Nicholas (Adele Achem)         1
# ..           ...                                                ...       ...
# 337          876                   Najib, Miss. Adele Kiamie "Jane"         1
# 338          880      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)         1
# 339          881       Shelley, Mrs. William (Imanita Parrish Hall)         1
# 340          888                       Graham, Miss. Margaret Edith         1
# 341          890                              Behr, Mr. Karl Howell         1
#
# [342 rows x 3 columns]

# %%
q = """
select
  passenger_info.PassengerId,
  passenger_info.Name,
  survival_status.Survived
from
  passenger_info
join
  survival_status
on
  passenger_info.PassengerId = survival_status.PassengerId
where
  Survived = 1;
"""

df = pd.read_sql(q, conn)

df
# Out:
#      PassengerId                                               Name  Survived
# 0              2  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 1              3                             Heikkinen, Miss. Laina         1
# 2              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 3              9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1
# 4             10                Nasser, Mrs. Nicholas (Adele Achem)         1
# ..           ...                                                ...       ...
# 337          876                   Najib, Miss. Adele Kiamie "Jane"         1
# 338          880      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)         1
# 339          881       Shelley, Mrs. William (Imanita Parrish Hall)         1
# 340          888                       Graham, Miss. Margaret Edith         1
# 341          890                              Behr, Mr. Karl Howell         1
#
# [342 rows x 3 columns]

# %%
# PassengerId, Name, Sex for Female

# %%
q = """
select
  passenger_info.PassengerId,
  Name,
  Sex
from
  passenger_info
where
  sex == "female"


"""

df = pd.read_sql(q, conn)

df
# Out:
#      PassengerId                                               Name     Sex
# 0              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 1              3                             Heikkinen, Miss. Laina  female
# 2              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 3              9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 4             10                Nasser, Mrs. Nicholas (Adele Achem)  female
# ..           ...                                                ...     ...
# 309          881       Shelley, Mrs. William (Imanita Parrish Hall)  female
# 310          883                       Dahlberg, Miss. Gerda Ulrika  female
# 311          886               Rice, Mrs. William (Margaret Norton)  female
# 312          888                       Graham, Miss. Margaret Edith  female
# 313          889           Johnston, Miss. Catherine Helen "Carrie"  female
#
# [314 rows x 3 columns]

# %%
# PassengerId, Name, Ticket for male

# %%
q = """
select
  passenger_info.PassengerId,
  Name,
  Ticket
from
  passenger_info
join
  ticket_info
on
  passenger_info.PassengerId = ticket_info.PassengerId
where
  sex == "male"
"""

df = pd.read_sql(q, conn)

df
# Out:
#      PassengerId                            Name            Ticket
# 0              1         Braund, Mr. Owen Harris         A/5 21171
# 1              5        Allen, Mr. William Henry            373450
# 2              6                Moran, Mr. James            330877
# 3              7         McCarthy, Mr. Timothy J             17463
# 4              8  Palsson, Master. Gosta Leonard            349909
# ..           ...                             ...               ...
# 572          884   Banfield, Mr. Frederick James  C.A./SOTON 34068
# 573          885          Sutehall, Mr. Henry Jr   SOTON/OQ 392076
# 574          887           Montvila, Rev. Juozas            211536
# 575          890           Behr, Mr. Karl Howell            111369
# 576          891             Dooley, Mr. Patrick            370376
#
# [577 rows x 3 columns]
