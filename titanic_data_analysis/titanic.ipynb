# %% [markdown]
# <a href="https://colab.research.google.com/github/byambaa1982/python_cources_for_beginers/blob/class_zero_burentugs/titanic_data_analysis/titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import regex as re
import os

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Titanic Data Analysis
# 1. How many people died?

# %%
Death_count = df[df['Survived']== 0]
Death_count
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# # Task 2:
# - How many people survived?

# %%
Life_count = df[df['Survived']== 1]
Life_count
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Task 3:
# - How many women died?
# - How many men died?
# - How many kids died?
# - How many boys died?

# %%
women_all = df[df['Sex']== 'female']
women_death = women_all[women_all['Survived']== 0]
women_death
# Out:
#      PassengerId  Survived  Pclass  \
# 14            15         0       3
# 18            19         0       3
# 24            25         0       3
# 38            39         0       3
# 40            41         0       3
# ..           ...       ...     ...
# 854          855         0       2
# 863          864         0       3
# 882          883         0       3
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 38                  Vander Planke, Miss. Augusta Maria  female  18.0      2
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Sex']== 'female']['Survived'].value_counts()
# Out:
# Survived
# 1    233
# 0     81
# Name: count, dtype: int64

# %%
men_all = df[df['Sex']== 'male']
men_death = men_all[men_all['Survived']== 0]
men_death
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df[df['Sex']== 'male']['Survived'].value_counts()
# Out:
# Survived
# 0    468
# 1    109
# Name: count, dtype: int64

# %%
kids_all = df[df['Age']< 18]
kids_death = kids_all[kids_all['Survived']== 0]
kids_death
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# 24            25         0       3            Palsson, Miss. Torborg Danira
# 50            51         0       3               Panula, Master. Juha Niilo
# 59            60         0       3       Goodwin, Master. William Frederick
# 63            64         0       3                    Skoog, Master. Harald
# 71            72         0       3               Goodwin, Miss. Lillian Amy
# 86            87         0       3                   Ford, Mr. William Neal
# 111          112         0       3                     Zabour, Miss. Hileni
# 114          115         0       3                    Attalah, Miss. Malake
# ...

# %%
kids_df = df[df['Age']< 18]['Survived'].value_counts()
kids_df
# Out:
# Survived
# 1    61
# 0    52
# Name: count, dtype: int64

# %%
boys_death = kids_death[kids_death['Sex']== 'male']
boys_death
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 16            17         0       3                     Rice, Master. Eugene
# 50            51         0       3               Panula, Master. Juha Niilo
# 59            60         0       3       Goodwin, Master. William Frederick
# 63            64         0       3                    Skoog, Master. Harald
# 86            87         0       3                   Ford, Mr. William Neal
# 138          139         0       3                      Osen, Mr. Olaf Elon
# 163          164         0       3                          Calic, Mr. Jovo
# 164          165         0       3             Panula, Master. Eino Viljami
# 171          172         0       3                     Rice, Master. Arthur
# 182          183         0       3    Asplund, Master. Clarence Gustaf Hugo
# ...

# %%
kids_all[kids_all['Sex']== 'male']['Survived'].value_counts()
# Out:
# Survived
# 0    35
# 1    23
# Name: count, dtype: int64

# %% [markdown]
# # Homework 1:
#
#
#
# 1. How many passengers were on board the Titanic?
#
# 2. How many male and female passengers were on board?
#
#
# 3. What is the average age of the passengers?
#
#
# 4. How many passengers survived, and how many did not?
#
# 5. Which passenger class had the most survivors?
#
#
# 6. What was the most common age of the passengers?
#
#
# 7. How many passengers had siblings or spouses aboard?
#
#
# 8. Find the youngest and oldest passengers on board.
#
#
# 9. What was the average fare paid by passengers?
#
#
# 10. How many passengers had missing data in the 'Age' column?

# %%
df['PassengerId'].count()
# Out:
# 891

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
average_age = df['Age'].median()
average_age
# Out:
# 28.0

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df[df['Survived']==1].groupby('Pclass')['Survived'].count()
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %%
df['Age'].mode()[0]
# Out:
# 24.0

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df['Age'].max()
# Out:
# 80.0

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Fare'].mode()[0]
# Out:
# 8.05

# %%
df['Age'].isna().sum()
# Out:
# 177
