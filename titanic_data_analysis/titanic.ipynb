# %% [markdown]
# <a href="https://colab.research.google.com/github/byambaa1982/python_cources_for_beginers/blob/class_zero_urangoo/titanic_data_analysis/titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import regex as re
import os

# %%
df = pd.read_csv('titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Titanic Data Analysis
# 1. How many people died?

# %%
died_count = df[df['Survived'] == 0].shape

print(f"Number of people who died {died_count}")
# Out:
# Number of people who died (549, 12)

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# # Task 2:
# - How many people survived?

# %%
Survived_count = df[df['Survived'] == 1].shape

print(f"Number of people who survived {Survived_count}")
# Out:
# Number of people who survived (342, 12)

# %% [markdown]
# # Task 3:
# - How many women died?
# - How many men died?
# - How many kids died?
# - How many boys died?

# %%
woman_count = df[df['Sex']== 'female'].shape[0]

# %%
man_count = df[df['Sex']== 'male'].shape[0]

# %%
children = df[df['Age']<=18]
print(children.shape)
# Out:
# (139, 12)

# %%
died_children = children[children['Survived']==0]
print(died_children.shape)
# Out:
# (69, 12)

# %%
died_boy = died_children[died_children['Sex']== 'male']

# %%
print(died_boy.shape)
# Out:
# (47, 12)

# %%
died_boy
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 16            17         0       3
# 50            51         0       3
# 59            60         0       3
# 63            64         0       3
# 86            87         0       3
# 138          139         0       3
# 144          145         0       2
# 163          164         0       3
# 164          165         0       3
# 171          172         0       3
# 175          176         0       3
# 182          183         0       3
# 228          229         0       2
# 266          267         0       3
# 278          279         0       3
# 282          283         0       3
# 333          334         0       3
# 352          353         0       3
# 371          372         0       3
# 385          386         0       2
# 386          387         0       3
# 424          425         0       3
# 433          434         0       3
# 480          481         0       3
# ...

# %%
boy = df[df['Age']<=18]
print(boy.shape)
# Out:
# (139, 12)

# %%
df3 = boy[boy['Survived']==0]
print(df3.shape)
# Out:
# (69, 12)

# %% [markdown]
# # Homework 1:
#
#
#
# 1. How many passengers were on board the Titanic?
#
# 2. How many male and female passengers were on board?
#
#
# 3. What is the average age of the passengers?
#
#
# 4. How many passengers survived, and how many did not?
#
# 5. Which passenger class had the most survivors?
#
#
# 6. What was the most common age of the passengers?
#
#
# 7. How many passengers had siblings or spouses aboard?
#
#
# 8. Find the youngest and oldest passengers on board.
#
#
# 9. What was the average fare paid by passengers?
#
#
# 10. How many passengers had missing data in the 'Age' column?

# %%
passenger = df[df['Age']<1000].shape[0]
print(passenger)
# Out:
# 714

# %%
women = df[df['Sex']== 'female']
print(women)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Out:
# 577

# %%
average_age = df['Age'].mean()

# %%
average_age
# Out:
# 29.69911764705882

# %%
survived_count = df['Survived'].sum()
not_survived_count = df['Survived'].count() - survived_count

# %%
most_common_age = df['Age'].mode()[0]

# %%
most_common_age
# Out:
# 24.0

# %%
youngest_passenger = df.loc[df['Age'].idxmin()]

# %%
youngest_passenger
# Out:
# PassengerId                                804
# Survived                                     1
# Pclass                                       3
# Name           Thomas, Master. Assad Alexander
# Sex                                       male
# Age                                       0.42
# SibSp                                        0
# Parch                                        1
# Ticket                                    2625
# Fare                                    8.5167
# Cabin                                      NaN
# Embarked                                     C
# Name: 803, dtype: object

# %%
oldest_passenger = df.loc[df['Age'].idxmax()]

# %%
oldest_passenger
# Out:
# PassengerId                                     631
# Survived                                          1
# Pclass                                            1
# Name           Barkworth, Mr. Algernon Henry Wilson
# Sex                                            male
# Age                                            80.0
# SibSp                                             0
# Parch                                             0
# Ticket                                        27042
# Fare                                           30.0
# Cabin                                           A23
# Embarked                                          S
# Name: 630, dtype: object

# %%
average_fare = df['Fare'].mean()

# %%
average_fare
# Out:
# 32.204207968574636

# %%
missing_age_count = df['Age'].isnull().sum()

# %%
missing_age_count
# Out:
# 177

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
pclass_count = df['Pclass'].value_counts()
pclass_count.plot(kind='bar')
plt.title('Number of Passengers by Class')
plt.xlabel('Passenger Class')
plt.ylable('Count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-60dfc343334d> in <cell line: 5>()
#       3 plt.title('Number of Passengers by Class')
#       4 plt.xlabel('Passenger Class')
# ----> 5 plt.ylable('Count')
#       6 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ylable'
