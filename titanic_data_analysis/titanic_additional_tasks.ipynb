# %% [markdown]
# <a href="https://colab.research.google.com/github/byambaa1982/python_cources_for_beginers/blob/grace/titanic_data_analysis/titanic_additional_tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import regex as re
import os

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Survival Rate by Gender
#
# - Task: Calculate the survival rate for male and female passengers.
#
# - Instruction: Use groupby() and mean() to analyze data.

# %%
survival_by_gender = df.groupby('Sex')['Survived'].mean()
survival_by_gender
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %% [markdown]
# # Age Distribution of Passengers
#
# - Task: Plot the distribution of passengers’ ages.
#
# - plotting histograms to visualize distributions.

# %%
# your code is here
df['Age'].plot(kind = 'hist', bins = 30, title = 'Age Distribution')
plt.ylabel('Count')
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'age')

# %% [markdown]
# # Average Fare Paid
#
# - Task: Find the average fare paid by passengers who survived and those who didn't.
#
# - Use: aggregation functions like mean().

# %%
# your code is here
fare_by_survival = df[df['Survived'] == 1]['Fare'].mean()
fare_by_survival2 = df[df['Survived'] == 0]['Fare'].mean()
print(f'Survived: ${fare_by_survival:.2f}')
print(f'Died: ${fare_by_survival2:.2f}')
# Out:
# Survived: $48.40
# Died: $22.12

# %% [markdown]
# # Richest Passenger
#
# - Task: Find the passenger who paid the highest fare.
#
# - Use: idxmax()

# %%
richest_passenger = "you code is here"
print(richest_passenger)
# Out:
# PassengerId                 259
# Survived                      1
# Pclass                        1
# Name           Ward, Miss. Anna
# Sex                      female
# Age                        35.0
# SibSp                         0
# Parch                         0
# Ticket                 PC 17755
# Fare                   512.3292
# Cabin                       NaN
# Embarked                      C
# Name: 258, dtype: object

# %% [markdown]
# # Survival Rate by Age Group
#
# - Task: Create age groups (children, adults, seniors) and calculate survival rates for each group.
#
# -  creating categories and grouping

# %%
bins = [0, 12, 18, 60, 100]
labels = ['Child', 'Teen', 'Adult', 'Senior']
# your code here
survival_by_agegroup
# Out:
# <ipython-input-20-aa55e597abe1>:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   survival_by_agegroup = df.groupby('AgeGroup')['Survived'].mean()
# AgeGroup
# Child     0.579710
# Teen      0.428571
# Adult     0.388788
# Senior    0.227273
# Name: Survived, dtype: float64

# %% [markdown]
# # Family Size and Survival
#
# - Task: Create a new column for family size (SibSp + Parch) and analyze how family size impacted survival.
#
# - Use: combine columns.

# %%
survival_by_familysize
# Out:
# FamilySize
# 0     0.303538
# 1     0.552795
# 2     0.578431
# 3     0.724138
# 4     0.200000
# 5     0.136364
# 6     0.333333
# 7     0.000000
# 10    0.000000
# Name: Survived, dtype: float64

# %% [markdown]
# # Finding a Specific Passenger
#
# - Task: Find a passenger by their name and explore their details.
#
# - Use: Work with text data and string matching.

# %%
passenger
# Out:
#      PassengerId  Survived  Pclass  \
# 149          150         0       2
# 151          152         1       1
# 159          160         0       3
# 186          187         1       3
# 252          253         0       1
# 260          261         0       3
# 336          337         0       1
# 347          348         1       3
# 364          365         0       3
# 372          373         0       3
# 415          416         0       3
# 560          561         0       3
# 670          671         1       2
# 679          680         1       1
# 684          685         0       2
# 758          759         0       3
# 778          779         0       3
# 803          804         1       3
# 806          807         0       1
# 828          829         1       3
# 841          842         0       2
# 879          880         1       1
#
#                                                   Name     Sex    Age  SibSp  \
# 149                  Byles, Rev. Thomas Roussel Davids    male  42.00      0
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.00      1
# 159                         Sage, Master. Thomas Henry    male    NaN      8
# 186    O'Brien, Mrs. Thomas (Johanna "Hannah" Godfrey)  female    NaN      1
# 252                          Stead, Mr. William Thomas    male  62.00      0
# 260                                  Smith, Mr. Thomas    male    NaN      0
# 336                          Pears, Mr. Thomas Clinton    male  29.00      1
# 347          Davison, Mrs. Thomas Henry (Mary E Finck)  female    NaN      1
# 364                                O'Brien, Mr. Thomas    male    NaN      1
# 372                         Beavan, Mr. William Thomas    male  19.00      0
# 415            Meek, Mrs. Thomas (Annie Louise Rowley)  female    NaN      0
# 560                           Morrow, Mr. Thomas Rowan    male    NaN      0
# 670  Brown, Mrs. Thomas William Solomon (Elizabeth ...  female  40.00      1
# 679                 Cardeza, Mr. Thomas Drake Martinez    male  36.00      0
# 684                  Brown, Mr. Thomas William Solomon    male  60.00      1
# 758                       Theobald, Mr. Thomas Leonard    male  34.00      0
# 778                            Kilgannon, Mr. Thomas J    male    NaN      0
# 803                    Thomas, Master. Assad Alexander    male   0.42      0
# 806                             Andrews, Mr. Thomas Jr    male  39.00      0
# 828                       McCormack, Mr. Thomas Joseph    male    NaN      0
# 841                           Mudd, Mr. Thomas Charles    male  16.00      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.00      0
#
#      Parch       Ticket      Fare        Cabin Embarked AgeGroup  FamilySize
# 149      0       244310   13.0000          NaN        S    Adult           0
# 151      0       113776   66.6000           C2        S    Adult           1
# 159      2     CA. 2343   69.5500          NaN        S      NaN          10
# 186      0       370365   15.5000          NaN        Q      NaN           1
# 252      0       113514   26.5500          C87        S   Senior           0
# 260      0       384461    7.7500          NaN        Q      NaN           0
# 336      0       113776   66.6000           C2        S    Adult           1
# 347      0       386525   16.1000          NaN        S      NaN           1
# 364      0       370365   15.5000          NaN        Q      NaN           1
# 372      0       323951    8.0500          NaN        S    Adult           0
# 415      0       343095    8.0500          NaN        S      NaN           0
# 560      0       372622    7.7500          NaN        Q      NaN           0
# 670      1        29750   39.0000          NaN        S    Adult           2
# 679      1     PC 17755  512.3292  B51 B53 B55        C    Adult           1
# 684      1        29750   39.0000          NaN        S    Adult           2
# 758      0       363294    8.0500          NaN        S    Adult           0
# 778      0        36865    7.7375          NaN        Q      NaN           0
# 803      1         2625    8.5167          NaN        C    Child           1
# 806      0       112050    0.0000          A36        S    Adult           0
# 828      0       367228    7.7500          NaN        Q      NaN           0
# 841      0  S.O./P.P. 3   10.5000          NaN        S     Teen           0
# 879      1        11767   83.1583          C50        C    Adult           1
