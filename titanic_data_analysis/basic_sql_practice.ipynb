# %% [markdown]
# <a href="https://colab.research.google.com/github/byambaa1982/python_cources_for_beginers/blob/class_zero_burentugs/titanic_data_analysis/basic_sql_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlite3

# %% [markdown]
# # SQL
#
# - Step 1. Download titanic.sqlite
#
# - step 2. Upload file into notebook
#
# - step 3. Run the first two cells

# %%
# Connect to the SQLite database
conn = sqlite3.connect('titanic.sqlite')

# Read the 'titanic' table into a pandas DataFrame
df = pd.read_sql('SELECT * FROM titanic', conn)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Use 'PassengerId', 'Name', 'Sex', 'Age' columns and save dataframe into database as passenger_info

# %%
# 1. Passenger Info Table
passenger_info = df[['PassengerId', 'Name', 'Sex', 'Age']]
passenger_info.to_sql('passenger_info', conn, if_exists='replace', index=False)

# 2. Ticket Info Table
ticket_info = df[['PassengerId', 'Ticket', 'Fare', 'Pclass']]
ticket_info.to_sql('ticket_info', conn, if_exists='replace', index=False)

# 3. Survival Status Table
survival_status = df[['PassengerId', 'Survived', 'Parch', 'SibSp']]
survival_status.to_sql('survival_status', conn, if_exists='replace', index=False)
# Out:
# 891

# %%
tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table'", conn)
print(tables)
# Out:
#               name
# 0          titanic
# 1   passenger_info
# 2      ticket_info
# 3  survival_status

# %% [markdown]
# # Find the Most Expensive Ticket Price
#
#
# - Objective: Identify the most expensive ticket price in the dataset.
# - Pandas: Use df['Fare'].max() to find the highest ticket price.
# - SQL: Write a query like SELECT MAX(Fare) FROM titanic;.

# %%
df['Fare'].max()
# Out:
# 512.3292

# %%
df = pd.read_sql("SELECT MAX(Fare) FROM titanic;", conn)
df
# Out:
#    MAX(Fare)
# 0   512.3292

# %% [markdown]
# # Task 1: Find the Youngest and Oldest Passenger

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].max()
# Out:
# 80.0

# %% [markdown]
# # Task 2: Count the Number of Passengers by Embarkation Port

# %%
query = '''
select Embarked, count(*) as Count from titanic GROUP BY Embarked
'''

df = pd.read_sql(query, conn)

df
# Out:
#   Embarked  Count
# 0     None      2
# 1        C    168
# 2        Q     77
# 3        S    644

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %% [markdown]
# # Task 3: List the Names of the Top 5 Wealthiest Passengers

# %%
query = '''
select Name, Fare from titanic order by fare desc limit 5
'''
df = pd.read_sql(query, conn)

df
# Out:
#                                  Name      Fare
# 0                    Ward, Miss. Anna  512.3292
# 1  Cardeza, Mr. Thomas Drake Martinez  512.3292
# 2              Lesurer, Mr. Gustave J  512.3292
# 3      Fortune, Mr. Charles Alexander  263.0000
# 4          Fortune, Miss. Mabel Helen  263.0000

# %%
# Your SQL code is here

# %% [markdown]
# # Task 4: Calculate the Average Fare by Passenger Class

# %%
df.groupby('Pclass')['Fare'].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
# Pandas
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %% [markdown]
# # Task 5: List All Passengers Who Were Traveling Alone

# %%
df[(df['SibSp'] == 0) & (df['Parch'] == 0)]
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 2              3         1       3        Heikkinen, Miss. Laina  female
# 4              5         0       3      Allen, Mr. William Henry    male
# 5              6         0       3              Moran, Mr. James    male
# 6              7         0       1       McCarthy, Mr. Timothy J    male
# 11            12         1       1      Bonnell, Miss. Elizabeth  female
# ..           ...       ...     ...                           ...     ...
# 884          885         0       3        Sutehall, Mr. Henry Jr    male
# 886          887         0       2         Montvila, Rev. Juozas    male
# 887          888         1       1  Graham, Miss. Margaret Edith  female
# 889          890         1       1         Behr, Mr. Karl Howell    male
# 890          891         0       3           Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# Your pandas code is here
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 2              3         1       3        Heikkinen, Miss. Laina  female
# 4              5         0       3      Allen, Mr. William Henry    male
# 5              6         0       3              Moran, Mr. James    male
# 6              7         0       1       McCarthy, Mr. Timothy J    male
# 11            12         1       1      Bonnell, Miss. Elizabeth  female
# ..           ...       ...     ...                           ...     ...
# 884          885         0       3        Sutehall, Mr. Henry Jr    male
# 886          887         0       2         Montvila, Rev. Juozas    male
# 887          888         1       1  Graham, Miss. Margaret Edith  female
# 889          890         1       1         Behr, Mr. Karl Howell    male
# 890          891         0       3           Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
q = '''
select * from titanic where SibSp = 0 and Parch = 0
'''
pd.read_sql(q, conn)
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 0              3         1       3        Heikkinen, Miss. Laina  female
# 1              5         0       3      Allen, Mr. William Henry    male
# 2              6         0       3              Moran, Mr. James    male
# 3              7         0       1       McCarthy, Mr. Timothy J    male
# 4             12         1       1      Bonnell, Miss. Elizabeth  female
# ..           ...       ...     ...                           ...     ...
# 532          885         0       3        Sutehall, Mr. Henry Jr    male
# 533          887         0       2         Montvila, Rev. Juozas    male
# 534          888         1       1  Graham, Miss. Margaret Edith  female
# 535          890         1       1         Behr, Mr. Karl Howell    male
# 536          891         0       3           Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
q = # Your code is here

pd.read_sql(q, conn)
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 0              3         1       3        Heikkinen, Miss. Laina  female
# 1              5         0       3      Allen, Mr. William Henry    male
# 2              6         0       3              Moran, Mr. James    male
# 3              7         0       1       McCarthy, Mr. Timothy J    male
# 4             12         1       1      Bonnell, Miss. Elizabeth  female
# ..           ...       ...     ...                           ...     ...
# 532          885         0       3        Sutehall, Mr. Henry Jr    male
# 533          887         0       2         Montvila, Rev. Juozas    male
# 534          888         1       1  Graham, Miss. Margaret Edith  female
# 535          890         1       1         Behr, Mr. Karl Howell    male
# 536          891         0       3           Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...
