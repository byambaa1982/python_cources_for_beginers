# %% [markdown]
# <a href="https://colab.research.google.com/github/byambaa1982/python_cources_for_beginers/blob/main/Mini%20Project%201/Pandas_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Working On CSV file

# %%
import pandas as pd

# %% [markdown]
# # Turn CSV file into Dataframe

# %%
df = pd.read_csv("twitter_data.csv")
print(df.shape)
# Out:
# (4579, 15)

# %%
df.head()
# Out:
#               tweet_id                                               text  \
# 0  1824462555873677626  Snowflakeのネイティブテーブルみたいに自動的にマイクロパーティショニングが当たるやつ...
# 1  1824456330708439311  Databricks is bringing an added layer of value...
# 2  1824473443267469719  Excited to announce the GA of Row &amp; Column...
# 3  1824450584243589123  End-user survey finds Snowflake, Databricks, a...
# 4  1824444380985405926  Ontology is the biggest advantage of $PLTR aft...
#
#                                            media_url  \
# 0                                                NaN
# 1  {'media_key': '3_1824456328594563072', 'type':...
# 2                                                NaN
# 3                                                NaN
# 4  {'media_key': '7_1824443146089984000', 'type':...
#
#                  created_at            author_id     keyword  \
# 0 2024-08-16 15:05:44+00:00             14156160  databricks
# 1 2024-08-16 14:41:00+00:00            182918785  databricks
# 2 2024-08-16 15:49:00+00:00            387795194  databricks
# 3 2024-08-16 14:18:10+00:00   986230825107812352  databricks
# 4 2024-08-16 13:53:31+00:00  1251929728904290304  databricks
#
#            modified liked followed replied  score  reposted  quote  \
# 0  2024-08-16-11-00    no       no      no      0       NaN    NaN
# 1  2024-08-16-11-00    no       no      no      0       NaN    NaN
# 2  2024-08-16-11-00    no       no      no      0       NaN    NaN
# 3  2024-08-16-11-00    no       no      no      0       NaN    NaN
# 4  2024-08-16-11-00    no       no      no      0       NaN    NaN
#
#         username  rn
# 0       legoboku   1
# 1         TBRinc   1
# 2  matthewgiglia   1
# 3  SalesTechStar   1
# 4  TechCryptoGuy   1

# %%
type(2024-01-19-10-29)
# Out:
#   File "<ipython-input-46-ede0ebb5f73d>", line 1
#     type(2024-01-19-10-29)
#               ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
df['text']
# Out:
# pandas.core.series.Series

# %%
type(df['created_at'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %% [markdown]
# # Task 1
#
# - Create new dataframe. Columns: username, keyword, liked, modified

# %%
df2 = df[['username', 'keyword', 'liked', 'modified']]

# %%
df2.shape
# Out:
# (4579, 4)

# %% [markdown]
# # Homework
#
# 1. Show how many different keywords?
# 2. Show the most frequent keyword.
# 3. Create df3 columns: author_id, text, and df4 author_id, username and then join them on author_id name joined_df

# %%
df['keyword'].unique()
# Out:
# array(['databricks', 'pyspark', 'axie', 'axie infinity', 'big data',
#        'SQL', 'dataEngineering', 'Scikit-learn', 'Kubernetes', 'NumPy',
#        'Matplotlib', 'javascript', 'NoSQL', 'Hadoop', 'python',
#        'Google Cloud', 'azure', 'Seaborn', 'Apache Kafka', 'TensorFlow',
#        'Spark', 'Docker', 'Jupyter Notebook', 'Elasticsearch', 'PyTorch',
#        'Microsoft Azure', 'Tableau', 'IBM Watson', 'Power BI', 'Pandas',
#        'AWS'], dtype=object)

# %%
df['keyword'].value_counts()
# Out:
# keyword
# big data            760
# databricks          666
# SQL                 632
# pyspark             382
# Pandas              215
# Spark               146
# Power BI            132
# Seaborn             123
# AWS                 122
# NumPy               114
# IBM Watson          114
# Docker              108
# PyTorch             103
# Google Cloud        103
# Jupyter Notebook     92
# Microsoft Azure      91
# Tableau              86
# Elasticsearch        84
# Matplotlib           79
# Scikit-learn         77
# NoSQL                69
# Apache Kafka         61
# Hadoop               61
# TensorFlow           49
# axie                 33
# Kubernetes           30
# axie infinity        18
# javascript           13
# azure                10
# python                4
# dataEngineering       2
# Name: count, dtype: int64

# %%
df2 = df[['author_id', 'username']]
only_head = df2.head()
only_head
# Out:
#              author_id       username
# 0             14156160       legoboku
# 1            182918785         TBRinc
# 2            387795194  matthewgiglia
# 3   986230825107812352  SalesTechStar
# 4  1251929728904290304  TechCryptoGuy

# %%
only_head.to_csv('test_file.csv', index = False)

# %%
new = df.loc[[1, 3, 4,5, 6, 7, 8], ['author_id', 'username', 'text']]
new
# Out:
#              author_id         username  \
# 1            182918785           TBRinc
# 3   986230825107812352    SalesTechStar
# 4  1251929728904290304    TechCryptoGuy
# 5           1394746741        bpcs_tech
# 6           1876561765    BricksterGary
# 7   967730353522839552    elias34976279
# 8  1804119532342247424  DavidsonMa41390
#
#                                                 text
# 1  Databricks is bringing an added layer of value...
# 3  End-user survey finds Snowflake, Databricks, a...
# 4  Ontology is the biggest advantage of $PLTR aft...
# 5  Blueprint Builder, Jim Donahoe, will be speaki...
# 6  The blog explores data streams from NASA satel...
# 7  @kargarage Microsoft SQL Server vs Microsoft A...
# 8  How Oracle Autonomous Database Connects with D...

# %%
new.to_csv('new_file.csv', index = False)

# %%
new_df = df[df['username']=='matthewgiglia']
new_df
# Out:
#               tweet_id                                               text  \
# 2  1824473443267469719  Excited to announce the GA of Row &amp; Column...
#
#   media_url                created_at  author_id     keyword  \
# 2       NaN 2024-08-16 15:49:00+00:00  387795194  databricks
#
#            modified liked followed replied  score  reposted  quote  \
# 2  2024-08-16-11-00    no       no      no      0       NaN    NaN
#
#         username  rn
# 2  matthewgiglia   1

# %%
new_df[['created_at', 'author_id', 'keyword']]
# Out:
#                  created_at  author_id     keyword
# 2 2024-08-16 15:49:00+00:00  387795194  databricks

# %%
df.loc[df['username']=='matthewgiglia', ['created_at', 'author_id', 'keyword']]
# Out:
#                  created_at  author_id     keyword
# 2 2024-08-16 15:49:00+00:00  387795194  databricks

# %%
df.columns
# Out:
# Index(['tweet_id', 'text', 'media_url', 'created_at', 'author_id', 'keyword',
#        'modified', 'liked', 'followed', 'replied', 'score', 'reposted',
#        'quote', 'username', 'rn'],
#       dtype='object')

# %%
df.loc[2]
# Out:
# tweet_id                                    1824473443267469719
# text          Excited to announce the GA of Row &amp; Column...
# media_url                                                   NaN
# created_at                            2024-08-16 15:49:00+00:00
# author_id                                             387795194
# keyword                                              databricks
# modified                                       2024-08-16-11-00
# liked                                                        no
# followed                                                     no
# replied                                                      no
# score                                                         0
# reposted                                                    NaN
# quote                                                       NaN
# username                                          matthewgiglia
# rn                                                            1
# Name: 2, dtype: object

# %% [markdown]
# # Homework
#
# 1. create 3 different tables each has one common column and 2 different columns
# 2. join them back
# 3. filter only keyword 'databricks'
# 4. filter only keyword 'pyspark' and show how many rows.

# %%
csv_to_df = pd.read_csv('new_file.csv')
csv_to_df
# Out:
#              author_id         username  \
# 0            182918785           TBRinc
# 1   986230825107812352    SalesTechStar
# 2  1251929728904290304    TechCryptoGuy
# 3           1394746741        bpcs_tech
# 4           1876561765    BricksterGary
# 5   967730353522839552    elias34976279
# 6  1804119532342247424  DavidsonMa41390
#
#                                                 text
# 0  Databricks is bringing an added layer of value...
# 1  End-user survey finds Snowflake, Databricks, a...
# 2  Ontology is the biggest advantage of $PLTR aft...
# 3  Blueprint Builder, Jim Donahoe, will be speaki...
# 4  The blog explores data streams from NASA satel...
# 5  @kargarage Microsoft SQL Server vs Microsoft A...
# 6  How Oracle Autonomous Database Connects with D...
